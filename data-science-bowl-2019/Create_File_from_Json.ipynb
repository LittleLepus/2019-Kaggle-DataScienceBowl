# %%
import pandas as pd

# %%
df1=pd.read_csv('train.csv')

# %%
df2=pd.read_csv('train_labels.csv')

# %%
df3=pd.read_csv('specs.csv')

# %%
full_tandt=pd.merge(df1,df2,on='game_session')

# %%
filtered_full_tandtw

# %%
df_comp=full_tandt.head(1000)

# %%
df_comp.head(10)
# Out:
#    event_id      game_session                 timestamp  \
# 0  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 1  db02c830  901acc108f55a5a1  2019-08-06T05:22:01.400Z
# 2  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:01.403Z
# 3  a52b92d5  901acc108f55a5a1  2019-08-06T05:22:05.242Z
# 4  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:05.244Z
# 5  28ed704e  901acc108f55a5a1  2019-08-06T05:22:07.812Z
# 6  a52b92d5  901acc108f55a5a1  2019-08-06T05:22:07.812Z
# 7  9d29771f  901acc108f55a5a1  2019-08-06T05:22:07.816Z
# 8  c74f40cd  901acc108f55a5a1  2019-08-06T05:22:08.427Z
# 9  28ed704e  901acc108f55a5a1  2019-08-06T05:22:09.742Z
#
#                                           event_data installation_id_x  \
# 0  {"version":"1.0","event_count":1,"game_time":0...          0006a69f
# 1  {"event_count":2,"game_time":37,"event_code":2...          0006a69f
# 2  {"description":"Pull three mushrooms out of th...          0006a69f
# ...

# %%
df_comp['game_session'].dtype
# Out:
# dtype('O')

# %%
evl=df_comp['event_data']
edf=[]
#for i in evl:
#print(pd.read_json(evl[1]))
samp=evl[7]
samp1=evl[2]
samp
# Out:
# '{"description":"That\'s one!","identifier":"Dot_ThatsOne","media_type":"audio","total_duration":600,"event_count":8,"game_time":6475,"event_code":3021}'

# %%
import json
loaded_json=json.loads(samp)
loaded_json
pd.DataFrame.from_dict([loaded_json])['coordinates'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coordinates'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d6536b3bff2e> in <module>
# ...

# %%
keys=[]
#evl=[samp,samp1]
for i in evl:
    loaded_json=json.loads(i)
    for j in list(loaded_json.keys()):
        if j not in keys:
            keys.append(j)
keys
# Out:
# ['version',
#  'event_count',
#  'game_time',
#  'event_code',
#  'description',
#  'identifier',
#  'media_type',
#  'total_duration',
#  'duration',
#  'height',
#  'coordinates',
#  'stumps',
#  'source',
#  'destination',
#  'correct',
#  'misses',
#  'session_duration',
#  'exit_type',
#  'stage_number',
#  'hat',
#  'caterpillar',
#  'hats',
#  'caterpillars',
#  'bird_height',
#  'hats_placed',
#  'buckets',
#  'target_bucket',
#  'mode',
#  'prompt',
#  'round_number',
#  'bucket',
#  'buckets_placed',
#  'cauldron',
#  'crystals',
#  'crystal_id',
#  'weight',
#  'side',
#  'left',
#  'right',
#  'pillars',
#  'chests']

# %%
loaded_json1=json.loads(samp1)
loaded_json1
pd.DataFrame.from_dict([loaded_json1])
# Out:
#                                          description  event_code  event_count  \
# 0  Pull three mushrooms out of the ground and ord...        3010            3
#
#    game_time         identifier media_type  total_duration
# 0         37  Dot_PullMushrooms      audio            3000

# %%
#create an empty data frame and populate it with every value
#replace with 0s where empty 
#add in where applicable
# index is event id
range(1,df_comp.shape[0]+1)

json_df=pd.DataFrame(index=range(1,df_comp.shape[0]+1),columns=keys)

# %%
json_df
# Out:
#      version event_count game_time event_code description identifier  \
# 1        NaN         NaN       NaN        NaN         NaN        NaN
# 2        NaN         NaN       NaN        NaN         NaN        NaN
# 3        NaN         NaN       NaN        NaN         NaN        NaN
# 4        NaN         NaN       NaN        NaN         NaN        NaN
# 5        NaN         NaN       NaN        NaN         NaN        NaN
# 6        NaN         NaN       NaN        NaN         NaN        NaN
# 7        NaN         NaN       NaN        NaN         NaN        NaN
# 8        NaN         NaN       NaN        NaN         NaN        NaN
# 9        NaN         NaN       NaN        NaN         NaN        NaN
# 10       NaN         NaN       NaN        NaN         NaN        NaN
# 11       NaN         NaN       NaN        NaN         NaN        NaN
# 12       NaN         NaN       NaN        NaN         NaN        NaN
# 13       NaN         NaN       NaN        NaN         NaN        NaN
# ...

# %%
def parse_j(j):
    loaded_json=json.loads(j)
    df=pd.DataFrame([loaded_json])
    return df

# %%
def check_add(k,df,val,ind):
    for i in df.columns:
        if k == i:
            df[i][ind]=val
    return df

# %%
p=1
for i in evl:
    lj=json.loads(i)
    for j in list(lj.keys()):
        check_add(j,json_df,lj[j],p)
    p=p+1

# %%
json_df.shape
# Out:
# (1000, 41)

# %%
json_df.isnull().sum()
# Out:
# version             983
# event_count           0
# game_time             0
# event_code            0
# description         755
# identifier          755
# media_type          755
# total_duration      876
# duration            695
# height              845
# coordinates         366
# stumps              910
# source              724
# destination         924
# correct             827
# misses              988
# session_duration    992
# exit_type           995
# stage_number        986
# hat                 866
# caterpillar         846
# hats                866
# caterpillars        823
# bird_height         943
# hats_placed         973
# buckets             992
# target_bucket       999
# mode                997
# prompt              998
# round_number        998
# bucket              994
# buckets_placed      993
# cauldron            997
# crystals            995
# crystal_id          996
# weight              944
# side                998
# left                948
# ...

# %%
json_df
# Out:
#      version event_count game_time event_code  \
# 1        1.0           1         0       2000
# 2        NaN           2        37       2025
# 3        NaN           3        37       3010
# 4        NaN           4      3901       3110
# 5        NaN           5      3901       3010
# 6        NaN           6      6475       4025
# 7        NaN           7      6475       3110
# 8        NaN           8      6475       3021
# 9        NaN           9      7084       3121
# 10       NaN          10      8400       4025
# 11       NaN          11      8400       3021
# 12       NaN          12      8926       3121
# 13       NaN          13      9502       4025
# 14       NaN          14      9502       3021
# 15       NaN          15     10018       4070
# 16       NaN          16     10210       3121
# 17       NaN          17     10210       2035
# 18       NaN          18     10210       2020
# 19       NaN          19     10210       3010
# ...

# %%
json_df['event_code'].value_counts()
# Out:
# 4070    283
# 4030    168
# 4025     85
# 4020     68
# 3010     57
# 3110     56
# 3020     38
# 3120     37
# 3021     29
# 4100     28
# 3121     28
# 4110     22
# 4040     20
# 2020     20
# 2000     17
# 2030     12
# 4035     10
# 2010      8
# 2035      6
# 2025      6
# 4090      2
# Name: event_code, dtype: int64

# %%
json_df.describe()['round']
# Out:
# count     638
# unique     49
# top         7
# freq       63
# Name: round, dtype: int64

# %%
def check_null(df,per):
    added_col=[]
    for i in df.columns:
        if df.isnull().sum()[i]/len(df[i])<per:
            added_col.append(i)
    
    return added_col

# %%
col_l=check_null(json_df,0.37)

# %%
def fill_in_null(df):
    for t in df.columns:
        if df.isnull().sum()[t]/len(df[t])==0:
            for i in df.columns:
                if i.dtype == 'int64':
                    from sklearn.linear_model import LogisticRegression
                    df_l=df.drop_na()
                    x=df_l.drop(i,axis=1)
                    y=df_l[i]
                    inst=LogisticRegression()
                    f=inst.fit(x,y)

                    i_n=df[i].isnull()

                    null_data=df[i_n]
                    null_data=null_data.drop(i,axis=1)

                    for l in null_data.columns:
                        if null_data.isnull().sum()[l]/len(null_data[l])==0:
                            null_data=null_data.drop(l,axis=1)


                    null_df=null_data.drop_na()
                    p=f.predict(null_df)

                    ind=1
                    for j in df[i]:
                        if j.isnull():
                            df[i][j]=p[ind]
                            ind=ind+1


                else:
                    from sklearn.linear_model import LinearRegression
                    inst=LinearRegression()
                    df_l=df.drop_na()
                    x=df_l.drop(i,axis=1)
                    y=df_l[i]
                    f=inst.fit(x,y)

                    i_n=df[i].isnull()
                    null_data=df[i_n]
                    null_data=null_data.drop(i,axis=1)

                    for l in null_data.columns:
                        if null_data.isnull().sum()[l]/len(null_data[l])==0:
                            null_data=null_data.drop(l,axis=1)

                    null_df=null_data.drop_na()
                    p=f.predict(null_df)

                    ind=1
                    for j in df[i]:
                        if j.isnull():
                            df[i][j]=p[ind]
                            ind=ind+1

    return df

# %%
df=json_df[col_l]

# %%
df.head()
# Out:
#   event_code event_count game_time level round
# 1       2000           1       NaN   NaN   NaN
# 2       2000           1       NaN   NaN   NaN
# 3       2000           1         0   NaN   NaN
# 4       3010           2        53   NaN   NaN
# 5       3110           3      6972   NaN   NaN

# %%
i_n=df[t].isnull()
i_n.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-503403d6a0a8> in <module>
# ----> 1 i_n=df[t].isnull()
#       2 i_n.value_counts()
#
# NameError: name 't' is not defined

# %%
def fill_in_null(df):
    for t in df.columns:
            if df.isnull().sum()[t]/len(df[t])!=0.0:
                for i in df.columns:

                    if df[i].dtype == 'int64' and df.isnull().sum()[i]/len(df[i])!=0.0:
                        from sklearn.linear_model import LogisticRegression

                        df_l=df.dropna()
                        x=df_l.drop(i,axis=1)
                        y=df_l[i]
                        inst=LogisticRegression()
                        f=inst.fit(x,y)

                        i_n=df[i].isnull()

                        null_data=df[i_n]
                        null_data=null_data.drop(i,axis=1)

                        null_df=null_data.fillna(0)


                        #null_df=null_data.dropna()
                        p=f.predict(null_df)

                        y=1
                        ind=0
                        for j in df[i]:
                            if str(j) == 'nan':
                                df[i][y]=p[ind]
                                y=y+1
                                ind=ind+1


                    if df[i].dtype == 'O' and df.isnull().sum()[i]/len(df[i])!=0.0:
                        from sklearn.linear_model import LinearRegression
                        inst=LinearRegression()

                        df_l=df.dropna()
                        x=df_l.drop(i,axis=1)
                        y=df_l[i]
                        f=inst.fit(x,y)

                        i_n=df[i].isnull()
                        null_data=df[i_n]
                        null_data=null_data.drop(i,axis=1)

                        null_df=null_data.fillna(0)

                        #null_df=null_data.dropna()
                        p=f.predict(null_df)


                        y=1
                        ind=0
                        for j in df[i]:
                            if str(j) == 'nan':
                                df[i][y]=p[ind]
                                y=y+1
                                ind=ind+1
    return df

# %%
new_fill_df=fill_in_null(df)
# Out:
# C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
new_fill_df.head()
# Out:
#   event_code event_count game_time    level      round
# 1       2000           1   10535.8  1.28839   0.222851
# 2       2000           1   10535.8  1.28839   0.222851
# 3       2000           1         0  1.01792 -0.0962715
# 4       3010           2        53  1.03615  -0.135573
# 5       3110           3      6972  1.19591  0.0958678

# %%
nr=[]
for i in range(1,1001):
    nr.append(i)

# %%
len(nr)
# Out:
# 1000

# %%
df_comp['TI']=nr

# %%
df_comp_ni=df_comp.set_index('TI')

# %%
new_fill_df.shape
# Out:
# (1000, 5)

# %%
final_df=pd.concat([new_fill_df,df_comp_ni], axis=1, ignore_index=True)

# %%
col1=df_comp.columns
col2=new_fill_df.columns
f_col=list(col2.append(col1))
f_col
# Out:
# ['event_code',
#  'event_count',
#  'game_time',
#  'level',
#  'round',
#  'event_id',
#  'game_session',
#  'timestamp',
#  'event_data',
#  'installation_id',
#  'event_count',
#  'event_code',
#  'game_time',
#  'title',
#  'type',
#  'world',
#  'TI']

# %%
import ast
f_col.remove('TI')

# %%
f_col
# Out:
# ['event_code',
#  'event_count',
#  'game_time',
#  'level',
#  'round',
#  'event_id',
#  'game_session',
#  'timestamp',
#  'event_data',
#  'installation_id',
#  'event_count',
#  'event_code',
#  'game_time',
#  'title',
#  'type',
#  'world']

# %%
k=[]
for i in range(0,16):
    k.append(i)

# %%
res = {k[i]: f_col[i] for i in range(len(k))}

# %%
res
# Out:
# {0: 'event_code',
#  1: 'event_count',
#  2: 'game_time',
#  3: 'level',
#  4: 'round',
#  5: 'event_id',
#  6: 'game_session',
#  7: 'timestamp',
#  8: 'event_data',
#  9: 'installation_id',
#  10: 'event_count',
#  11: 'event_code',
#  12: 'game_time',
#  13: 'title',
#  14: 'type',
#  15: 'world'}

# %%
final_df.rename(columns=res,inplace=True)

# %%
final_df.head()
# Out:
#    event_code  event_count  game_time    level      round  event_id  \
# 1        2000            1    10535.8  1.28839   0.222851  27253bdc
# 2        2000            1    10535.8  1.28839   0.222851  27253bdc
# 3        2000            1          0  1.01792 -0.0962715  77261ab5
# 4        3010            2         53  1.03615  -0.135573  b2dba42b
# 5        3110            3       6972  1.19591  0.0958678  1bb5fbdb
#
#        game_session                 timestamp  \
# 1  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 2  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 3  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 4  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 5  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2             {"event_code": 2000, "event_count": 1}        0001e90f
# ...

# %%
final_df.drop('event_data',axis=1,inplace=True)

# %%
test_df.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
full_tandt=pd.merge(final_df,test_df,on='game_session')

# %%
full_tandt.head()
# Out:
# Empty DataFrame
# Columns: [event_code, event_count, game_time, level, round, event_id, game_session, timestamp, installation_id_x, event_count, event_code, game_time, title_x, type, world, installation_id_y, title_y, num_correct, num_incorrect, accuracy, accuracy_group]
# Index: []
#
# [0 rows x 21 columns]

# %%
y=1
ind=0
for j in df[i]:
    if str(j) == 'nan':
        df[i][y]=p[ind]
        y=y+1
        ind=ind+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df[i][2]

# %%
df[i][y]=p[ind]

# %%
p[1]

# %%
p[ind]

# %%
str(df['game_time'][1])=='nan'

# %%
null_data=df[i_n]
null_data
null_data=null_data.drop(i,axis=1)
null_data

# %%
null_df

# %%
from sklearn.linear_model import LinearRegression

# %%
json_df['version'][1]

# %%
json_df['version'].isnull()

# %%
json_df['game_session']=list(df['game_session'])

# %%
json_df.head()

# %%
len(df['game_session'])

# %%
fullsub=[]
def parse_sub_json(df):
    for i in df.columns:
        for j in df[i]:
            if j != None:
                if  '{' in str(j):
                    fullsub.append(j)
                    print(j)
    return fullsub

# %%
parse_sub_json(json_df)

# %%
fullsub

# %%
#evl=[samp,samp1]
def get_the_keys(l):
    keys=[]
    for i in l:
        loaded_json=json.loads(str(i))
        for j in list(loaded_json.keys()):
            if j not in keys:
                keys.append(j)
    return keys

# %%
get_the_keys(fullsub)

# %%
d_list=[{"pie":1,"past":4},{"pie":6,"pot":8}]

# %%
d=pd.DataFrame()
di=pd.DataFrame([d_list[1]])
df=pd.DataFrame([d_list[2]])
df.append(di)
print(di)

# %%
d_2= [{'size': 3,
   'position': {'x': 611, 'y': 109, 'stage_width': 1015, 'stage_height': 762}},
  {'size': 2,
   'position': {'x': 358, 'y': 154, 'stage_width': 1015, 'stage_height': 762}},
  {'size': 1,
   'position': {'x': 357,
    'y': 161,
    'stage_width': 1015,
    'stage_height': 762}}]

# %%
for i in d_2:
    print(i)

# %%
df1 =pd.DataFrame([d_list[0]]) 
print(df1)
# Creating the Second Dataframe using dictionary 
df2 = pd.DataFrame([d_list[1]]) 
  
# for appending df2 at the end of df1 
df1.append(df2, ignore_index = True)

# %%
d_list[1]
