# %%
import pandas as pd

# %%
df1=pd.read_csv('train.csv')

# %%
df1.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
filtered_df=df1[(df1['title']=='Cart Balancer (Assessment)') | (df1['title']=='Cauldron Filler (Assessment)') | (df1['title']=='Mushroom Sorter (Assessment)') | (df1['title']=='Chest Sorter (Assessment)') | (df1['title']=='Bird Measurer (Assessment)')]

# %%
filtered_df.shape
# Out:
# (925345, 11)

# %%
df2=pd.read_csv('train_labels.csv')

# %%
df2.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
filtered_df['title'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    199595
# Chest Sorter (Assessment)       190318
# Bird Measurer (Assessment)      190164
# Cauldron Filler (Assessment)    181925
# Cart Balancer (Assessment)      163343
# Name: title, dtype: int64

# %%
first_m=pd.merge(filtered_df,df3,on='event_id')

# %%
df2['title'].value_counts()
# Out:
# Cart Balancer (Assessment)      4151
# Cauldron Filler (Assessment)    4055
# Mushroom Sorter (Assessment)    3757
# Chest Sorter (Assessment)       2981
# Bird Measurer (Assessment)      2746
# Name: title, dtype: int64

# %%
df3=pd.read_csv('specs.csv')

# %%
df3.head()
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
first_m=pd.merge(df1,df3,on='event_id')

# %%
first_m.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  27253bdc  091587ed87b9637c  2019-09-06T18:10:51.183Z
# 3  27253bdc  3fce4f09769ff0b7  2019-09-06T18:18:11.250Z
# 4  27253bdc  04168b61c0650977  2019-09-06T18:18:42.392Z
#
#                                event_data installation_id  event_count  \
# 0  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 1  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 2  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 3  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 4  {"event_code": 2000, "event_count": 1}        0001e90f            1
#
#    event_code  game_time                    title  type        world  \
# 0        2000          0  Welcome to Lost Lagoon!  Clip         NONE
# 1        2000          0     Magma Peak - Level 1  Clip    MAGMAPEAK
# 2        2000          0     Magma Peak - Level 2  Clip    MAGMAPEAK
# 3        2000          0  Tree Top City - Level 1  Clip  TREETOPCITY
# 4        2000          0         Ordering Spheres  Clip  TREETOPCITY
#
#                                                 info  \
# 0  This event is triggered when a video starts pl...
# 1  This event is triggered when a video starts pl...
# 2  This event is triggered when a video starts pl...
# 3  This event is triggered when a video starts pl...
# 4  This event is triggered when a video starts pl...
#
#                                                 args
# 0  [{"name":"event_count","type":"int","info":"se...
# 1  [{"name":"event_count","type":"int","info":"se...
# 2  [{"name":"event_count","type":"int","info":"se...
# 3  [{"name":"event_count","type":"int","info":"se...
# 4  [{"name":"event_count","type":"int","info":"se...

# %%
full_tandt=pd.merge(first_m,df2,on='installation_id')

# %%
full_tandt.head()
# Out:
#    event_id    game_session_x                 timestamp  \
# 0  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 1  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 2  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 3  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 4  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
#
#                                event_data installation_id  event_count  \
# 0  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 1  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 2  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 3  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 4  {"event_code": 2000, "event_count": 1}        0006a69f            1
#
#    event_code  game_time                  title_x  type world  \
# 0        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 1        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 2        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 3        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 4        2000          0  Welcome to Lost Lagoon!  Clip  NONE
#
#                                                 info  \
# 0  This event is triggered when a video starts pl...
# 1  This event is triggered when a video starts pl...
# 2  This event is triggered when a video starts pl...
# 3  This event is triggered when a video starts pl...
# 4  This event is triggered when a video starts pl...
#
#                                                 args    game_session_y  \
# 0  [{"name":"event_count","type":"int","info":"se...  6bdf9623adc94d89
# 1  [{"name":"event_count","type":"int","info":"se...  77b8ee947eb84b4e
# 2  [{"name":"event_count","type":"int","info":"se...  901acc108f55a5a1
# 3  [{"name":"event_count","type":"int","info":"se...  9501794defd84e4d
# 4  [{"name":"event_count","type":"int","info":"se...  a9ef3ecb3d1acc6a
#
#                         title_y  num_correct  num_incorrect  accuracy  \
# 0  Mushroom Sorter (Assessment)            1              0       1.0
# 1    Bird Measurer (Assessment)            0             11       0.0
# 2  Mushroom Sorter (Assessment)            1              0       1.0
# 3  Mushroom Sorter (Assessment)            1              1       0.5
# 4    Bird Measurer (Assessment)            1              0       1.0
#
#    accuracy_group
# 0               3
# 1               0
# 2               3
# 3               2
# 4               3

# %%
final_filter_df=full_tandt[(full_tandt['title_x']==full_tandt['title_y'])]

# %%
final_filter_df.shape
# Out:
# (3377485, 19)

# %%
final_filter_df['title_x'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    850557
# Cauldron Filler (Assessment)    826553
# Bird Measurer (Assessment)      585632
# Chest Sorter (Assessment)       563505
# Cart Balancer (Assessment)      551238
# Name: title_x, dtype: int64

# %%
final_filter_df['title_y'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    850557
# Cauldron Filler (Assessment)    826553
# Bird Measurer (Assessment)      585632
# Chest Sorter (Assessment)       563505
# Cart Balancer (Assessment)      551238
# Name: title_y, dtype: int64

# %%
full_tandt['title_x'].value_counts()
# Out:
# Scrub-A-Dub                      8194412
# Bottle Filler (Activity)         6764681
# Chow Time                        5745828
# Sandcastle Builder (Activity)    5315848
# Crystals Rule                    4909354
# Bug Measurer (Activity)          4396723
# Fireworks (Activity)             4268736
# Bubble Bath                      4157600
# Pan Balance                      4149101
# Dino Drink                       3416337
# Dino Dive                        3407653
# Happy Camel                      3330595
# Chicken Balancer (Activity)      3233470
# Air Show                         3205929
# Flower Waterer (Activity)        3177810
# All Star Sorting                 3052537
# Mushroom Sorter (Assessment)     2914510
# Cauldron Filler (Assessment)     2796730
# Bird Measurer (Assessment)       2714330
# Chest Sorter (Assessment)        2570481
# Watering Hole (Activity)         2511416
# Leaf Leader                      2354373
# Egg Dropper (Activity)           2181664
# Cart Balancer (Assessment)       1941801
# Magma Peak - Level 2               91856
# Crystal Caves - Level 2            83754
# Tree Top City - Level 2            82688
# Crystal Caves - Level 3            79786
# Welcome to Lost Lagoon!            75155
# Tree Top City - Level 3            71614
# Ordering Spheres                   67589
# Slop Problem                       53372
# Pirate's Tale                      51264
# Magma Peak - Level 1               49627
# 12 Monkeys                         49045
# Tree Top City - Level 1            48490
# Treasure Map                       47655
# Crystal Caves - Level 1            46906
# Balancing Act                      39155
# Lifting Heavy Things               39070
# Costume Box                        37737
# Honey Cake                         32235
# Heavy, Heavier, Heaviest           31842
# Rulers                             31210
# Name: title_x, dtype: int64

# %%
full_tandt['title_y'].value_counts()
# Out:
# Cauldron Filler (Assessment)    21220604
# Mushroom Sorter (Assessment)    20506353
# Cart Balancer (Assessment)      19764464
# Bird Measurer (Assessment)      15370714
# Chest Sorter (Assessment)       14959834
# Name: title_y, dtype: int64

# %%
full_tandt['type'].value_counts()
# Out:
# Game          45923719
# Activity      31850348
# Assessment    12937852
# Clip           1110050
# Name: type, dtype: int64

# %%
final_filter_df.head()
# Out:
#        event_id    game_session_x                 timestamp  \
# 10535  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10537  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10538  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10540  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
# 10542  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
#
#                                               event_data installation_id  \
# 10535  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10537  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10538  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10540  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10542  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
#
#        event_count  event_code  game_time                       title_x  \
# 10535            1        2000          0  Mushroom Sorter (Assessment)
# 10537            1        2000          0  Mushroom Sorter (Assessment)
# 10538            1        2000          0  Mushroom Sorter (Assessment)
# 10540            1        2000          0  Mushroom Sorter (Assessment)
# 10542            1        2000          0  Mushroom Sorter (Assessment)
#
#              type        world  \
# 10535  Assessment  TREETOPCITY
# 10537  Assessment  TREETOPCITY
# 10538  Assessment  TREETOPCITY
# 10540  Assessment  TREETOPCITY
# 10542  Assessment  TREETOPCITY
#
#                                                     info  \
# 10535  The start game event is triggered at the very ...
# 10537  The start game event is triggered at the very ...
# 10538  The start game event is triggered at the very ...
# 10540  The start game event is triggered at the very ...
# 10542  The start game event is triggered at the very ...
#
#                                                     args    game_session_y  \
# 10535  [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 10537  [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 10538  [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 10540  [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 10542  [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
#
#                             title_y  num_correct  num_incorrect  accuracy  \
# 10535  Mushroom Sorter (Assessment)            1              0       1.0
# 10537  Mushroom Sorter (Assessment)            1              0       1.0
# 10538  Mushroom Sorter (Assessment)            1              1       0.5
# 10540  Mushroom Sorter (Assessment)            1              0       1.0
# 10542  Mushroom Sorter (Assessment)            1              0       1.0
#
#        accuracy_group
# 10535               3
# 10537               3
# 10538               2
# 10540               3
# 10542               3

# %%
ffd_df=final_filter_df[(final_filter_df['event_code']==4100)|(final_filter_df['event_code']==4110)]

# %%
ffd_df['title_x'].value_counts()
# Out:
# Bird Measurer (Assessment)      49556
# Cauldron Filler (Assessment)    41388
# Chest Sorter (Assessment)       32704
# Mushroom Sorter (Assessment)    31620
# Cart Balancer (Assessment)      24749
# Name: title_x, dtype: int64

# %%
ffd_df
# Out:
#           event_id    game_session_x                 timestamp  \
# 11185     25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 11187     25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 11188     25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 11190     25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 11192     25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 11193     25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 11195     25fa8af4  9501794defd84e4d  2019-08-06T20:35:12.290Z
# 11197     25fa8af4  9501794defd84e4d  2019-08-06T20:35:12.290Z
# 11198     25fa8af4  9501794defd84e4d  2019-08-06T20:35:12.290Z
# 11200     25fa8af4  9501794defd84e4d  2019-08-06T20:35:16.846Z
# 11202     25fa8af4  9501794defd84e4d  2019-08-06T20:35:16.846Z
# 11203     25fa8af4  9501794defd84e4d  2019-08-06T20:35:16.846Z
# 15711     17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 15714     17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 15716     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 15719     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 15721     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 15724     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 15726     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 15729     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 15731     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 15734     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 15736     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 15739     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 15741     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 15744     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 15746     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 15749     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 15751     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# 15754     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# ...            ...               ...                       ...
# 91820617  93b353f2  89327730a963baf8  2019-07-29T16:50:43.039Z
# 91820824  d122731b  0963cf75a2c46eb2  2019-10-10T12:11:38.397Z
# 91821530  93b353f2  be404f342567152a  2019-07-29T02:43:49.148Z
# 91821531  93b353f2  be404f342567152a  2019-07-29T02:43:49.148Z
# 91821532  93b353f2  be404f342567152a  2019-07-29T02:43:49.148Z
# 91821533  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:47.219Z
# 91821534  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:47.219Z
# 91821535  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:47.219Z
# 91821536  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:55.178Z
# 91821537  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:55.178Z
# 91821538  93b353f2  d80626fa2dfc3d1a  2019-07-29T02:44:55.178Z
# 91821539  93b353f2  e7742e2273276d2b  2019-07-29T02:51:41.903Z
# 91821540  93b353f2  e7742e2273276d2b  2019-07-29T02:51:41.903Z
# 91821541  93b353f2  e7742e2273276d2b  2019-07-29T02:51:41.903Z
# 91821542  93b353f2  e7742e2273276d2b  2019-07-29T02:51:48.848Z
# 91821543  93b353f2  e7742e2273276d2b  2019-07-29T02:51:48.848Z
# 91821544  93b353f2  e7742e2273276d2b  2019-07-29T02:51:48.848Z
# 91821746  93b353f2  29d49201b23eaa0f  2019-07-25T01:04:51.408Z
# 91821842  93b353f2  41f5106b9b6f1aee  2019-08-19T23:04:17.191Z
# 91821843  93b353f2  41f5106b9b6f1aee  2019-08-19T23:04:42.204Z
# 91821844  93b353f2  41f5106b9b6f1aee  2019-08-19T23:04:58.157Z
# 91821845  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:07.993Z
# 91821846  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:11.209Z
# 91821847  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:15.622Z
# 91821848  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:18.401Z
# 91821849  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:20.913Z
# 91821850  93b353f2  41f5106b9b6f1aee  2019-08-19T23:05:23.259Z
# 91821923  93b353f2  bdaaa3f243a3663c  2019-09-05T19:59:19.891Z
# 91821924  93b353f2  bdaaa3f243a3663c  2019-09-05T19:59:44.482Z
# 91821965  93b353f2  c9a323ec3617fffc  2019-07-28T16:19:29.381Z
#
#                                                  event_data installation_id  \
# 11185     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11187     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11188     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11190     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11192     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11193     {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 11195     {"correct":false,"stumps":[3,2,5],"event_count...        0006a69f
# 11197     {"correct":false,"stumps":[3,2,5],"event_count...        0006a69f
# 11198     {"correct":false,"stumps":[3,2,5],"event_count...        0006a69f
# 11200     {"correct":true,"stumps":[2,3,5],"event_count"...        0006a69f
# 11202     {"correct":true,"stumps":[2,3,5],"event_count"...        0006a69f
# 11203     {"correct":true,"stumps":[2,3,5],"event_count"...        0006a69f
# 15711     {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 15714     {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 15716     {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 15719     {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 15721     {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 15724     {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 15726     {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
# 15729     {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
# 15731     {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 15734     {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 15736     {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 15739     {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 15741     {"correct":false,"caterpillars":[11,8,2],"even...        0006a69f
# 15744     {"correct":false,"caterpillars":[11,8,2],"even...        0006a69f
# 15746     {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 15749     {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 15751     {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 15754     {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# ...                                                     ...             ...
# 91820617  {"correct":false,"pillars":[],"event_count":12...        6cc7ae2e
# 91820824  {"correct":true,"left":[{"id":"gem07","weight"...        c7fcf68c
# 91821530  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821531  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821532  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821533  {"correct":false,"pillars":[2,3,1],"event_coun...        60283b63
# 91821534  {"correct":false,"pillars":[2,3,1],"event_coun...        60283b63
# 91821535  {"correct":false,"pillars":[2,3,1],"event_coun...        60283b63
# 91821536  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821537  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821538  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821539  {"correct":false,"pillars":[2,1,3],"event_coun...        60283b63
# 91821540  {"correct":false,"pillars":[2,1,3],"event_coun...        60283b63
# 91821541  {"correct":false,"pillars":[2,1,3],"event_coun...        60283b63
# 91821542  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821543  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821544  {"correct":true,"pillars":[1,2,3],"event_count...        60283b63
# 91821746  {"correct":true,"pillars":[1,2,3],"event_count...        901ecfe3
# 91821842  {"correct":false,"pillars":[2,1,3],"event_coun...        9b7d6baa
# 91821843  {"correct":false,"pillars":[1,3,2],"event_coun...        9b7d6baa
# 91821844  {"correct":false,"pillars":[2,1,3],"event_coun...        9b7d6baa
# 91821845  {"correct":false,"pillars":[3,2,1],"event_coun...        9b7d6baa
# 91821846  {"correct":false,"pillars":[2,3,1],"event_coun...        9b7d6baa
# 91821847  {"correct":false,"pillars":[2,1,3],"event_coun...        9b7d6baa
# 91821848  {"correct":false,"pillars":[3,1,2],"event_coun...        9b7d6baa
# 91821849  {"correct":false,"pillars":[1,3,2],"event_coun...        9b7d6baa
# 91821850  {"correct":true,"pillars":[1,2,3],"event_count...        9b7d6baa
# 91821923  {"correct":false,"pillars":[2],"event_count":3...        9d570bf2
# 91821924  {"correct":false,"pillars":[0,0],"event_count"...        9d570bf2
# 91821965  {"correct":true,"pillars":[1,2,3],"event_count...        db2ab253
#
#           event_count  event_code  game_time                       title_x  \
# 11185              44        4100      31011  Mushroom Sorter (Assessment)
# 11187              44        4100      31011  Mushroom Sorter (Assessment)
# 11188              44        4100      31011  Mushroom Sorter (Assessment)
# 11190              30        4100      18026  Mushroom Sorter (Assessment)
# 11192              30        4100      18026  Mushroom Sorter (Assessment)
# 11193              30        4100      18026  Mushroom Sorter (Assessment)
# 11195              29        4100      18484  Mushroom Sorter (Assessment)
# 11197              29        4100      18484  Mushroom Sorter (Assessment)
# 11198              29        4100      18484  Mushroom Sorter (Assessment)
# 11200              38        4100      23043  Mushroom Sorter (Assessment)
# 11202              38        4100      23043  Mushroom Sorter (Assessment)
# 11203              38        4100      23043  Mushroom Sorter (Assessment)
# 15711              29        4110      35771    Bird Measurer (Assessment)
# 15714              29        4110      35771    Bird Measurer (Assessment)
# 15716              35        4110      42805    Bird Measurer (Assessment)
# 15719              35        4110      42805    Bird Measurer (Assessment)
# 15721              40        4110      47388    Bird Measurer (Assessment)
# 15724              40        4110      47388    Bird Measurer (Assessment)
# 15726              45        4110      50605    Bird Measurer (Assessment)
# 15729              45        4110      50605    Bird Measurer (Assessment)
# 15731              50        4110      54822    Bird Measurer (Assessment)
# 15734              50        4110      54822    Bird Measurer (Assessment)
# 15736              53        4110      58280    Bird Measurer (Assessment)
# 15739              53        4110      58280    Bird Measurer (Assessment)
# 15741              58        4110      62256    Bird Measurer (Assessment)
# 15744              58        4110      62256    Bird Measurer (Assessment)
# 15746              63        4110      67164    Bird Measurer (Assessment)
# 15749              63        4110      67164    Bird Measurer (Assessment)
# 15751              70        4110      73056    Bird Measurer (Assessment)
# 15754              70        4110      73056    Bird Measurer (Assessment)
# ...               ...         ...        ...                           ...
# 91820617           12        4100       8257     Chest Sorter (Assessment)
# 91820824           23        4100      19897    Cart Balancer (Assessment)
# 91821530           37        4100      43194     Chest Sorter (Assessment)
# 91821531           37        4100      43194     Chest Sorter (Assessment)
# 91821532           37        4100      43194     Chest Sorter (Assessment)
# 91821533           32        4100      36656     Chest Sorter (Assessment)
# 91821534           32        4100      36656     Chest Sorter (Assessment)
# 91821535           32        4100      36656     Chest Sorter (Assessment)
# 91821536           47        4100      44607     Chest Sorter (Assessment)
# 91821537           47        4100      44607     Chest Sorter (Assessment)
# 91821538           47        4100      44607     Chest Sorter (Assessment)
# 91821539           27        4100      24141     Chest Sorter (Assessment)
# 91821540           27        4100      24141     Chest Sorter (Assessment)
# 91821541           27        4100      24141     Chest Sorter (Assessment)
# 91821542           38        4100      31091     Chest Sorter (Assessment)
# 91821543           38        4100      31091     Chest Sorter (Assessment)
# 91821544           38        4100      31091     Chest Sorter (Assessment)
# 91821746           25        4100      21272     Chest Sorter (Assessment)
# 91821842           33        4100      29556     Chest Sorter (Assessment)
# 91821843           60        4100      54568     Chest Sorter (Assessment)
# 91821844           77        4100      70519     Chest Sorter (Assessment)
# 91821845           91        4100      80353     Chest Sorter (Assessment)
# 91821846           97        4100      83569     Chest Sorter (Assessment)
# 91821847          103        4100      87986     Chest Sorter (Assessment)
# 91821848          108        4100      90766     Chest Sorter (Assessment)
# 91821849          113        4100      93270     Chest Sorter (Assessment)
# 91821850          119        4100      95620     Chest Sorter (Assessment)
# 91821923           35        4100      34409     Chest Sorter (Assessment)
# 91821924           54        4100      59008     Chest Sorter (Assessment)
# 91821965           38        4100      38697     Chest Sorter (Assessment)
#
#                 type         world  \
# 11185     Assessment   TREETOPCITY
# 11187     Assessment   TREETOPCITY
# 11188     Assessment   TREETOPCITY
# 11190     Assessment   TREETOPCITY
# 11192     Assessment   TREETOPCITY
# 11193     Assessment   TREETOPCITY
# 11195     Assessment   TREETOPCITY
# 11197     Assessment   TREETOPCITY
# 11198     Assessment   TREETOPCITY
# 11200     Assessment   TREETOPCITY
# 11202     Assessment   TREETOPCITY
# 11203     Assessment   TREETOPCITY
# 15711     Assessment   TREETOPCITY
# 15714     Assessment   TREETOPCITY
# 15716     Assessment   TREETOPCITY
# 15719     Assessment   TREETOPCITY
# 15721     Assessment   TREETOPCITY
# 15724     Assessment   TREETOPCITY
# 15726     Assessment   TREETOPCITY
# 15729     Assessment   TREETOPCITY
# 15731     Assessment   TREETOPCITY
# 15734     Assessment   TREETOPCITY
# 15736     Assessment   TREETOPCITY
# 15739     Assessment   TREETOPCITY
# 15741     Assessment   TREETOPCITY
# 15744     Assessment   TREETOPCITY
# 15746     Assessment   TREETOPCITY
# 15749     Assessment   TREETOPCITY
# 15751     Assessment   TREETOPCITY
# 15754     Assessment   TREETOPCITY
# ...              ...           ...
# 91820617  Assessment  CRYSTALCAVES
# 91820824  Assessment  CRYSTALCAVES
# 91821530  Assessment  CRYSTALCAVES
# 91821531  Assessment  CRYSTALCAVES
# 91821532  Assessment  CRYSTALCAVES
# 91821533  Assessment  CRYSTALCAVES
# 91821534  Assessment  CRYSTALCAVES
# 91821535  Assessment  CRYSTALCAVES
# 91821536  Assessment  CRYSTALCAVES
# 91821537  Assessment  CRYSTALCAVES
# 91821538  Assessment  CRYSTALCAVES
# 91821539  Assessment  CRYSTALCAVES
# 91821540  Assessment  CRYSTALCAVES
# 91821541  Assessment  CRYSTALCAVES
# 91821542  Assessment  CRYSTALCAVES
# 91821543  Assessment  CRYSTALCAVES
# 91821544  Assessment  CRYSTALCAVES
# 91821746  Assessment  CRYSTALCAVES
# 91821842  Assessment  CRYSTALCAVES
# 91821843  Assessment  CRYSTALCAVES
# 91821844  Assessment  CRYSTALCAVES
# 91821845  Assessment  CRYSTALCAVES
# 91821846  Assessment  CRYSTALCAVES
# 91821847  Assessment  CRYSTALCAVES
# 91821848  Assessment  CRYSTALCAVES
# 91821849  Assessment  CRYSTALCAVES
# 91821850  Assessment  CRYSTALCAVES
# 91821923  Assessment  CRYSTALCAVES
# 91821924  Assessment  CRYSTALCAVES
# 91821965  Assessment  CRYSTALCAVES
#
#                                                        info  \
# 11185     This event occurs when the player on the done ...
# 11187     This event occurs when the player on the done ...
# 11188     This event occurs when the player on the done ...
# 11190     This event occurs when the player on the done ...
# 11192     This event occurs when the player on the done ...
# 11193     This event occurs when the player on the done ...
# 11195     This event occurs when the player on the done ...
# 11197     This event occurs when the player on the done ...
# 11198     This event occurs when the player on the done ...
# 11200     This event occurs when the player on the done ...
# 11202     This event occurs when the player on the done ...
# 11203     This event occurs when the player on the done ...
# 15711     This event occurs when the player on the done ...
# 15714     This event occurs when the player on the done ...
# 15716     This event occurs when the player on the done ...
# 15719     This event occurs when the player on the done ...
# 15721     This event occurs when the player on the done ...
# 15724     This event occurs when the player on the done ...
# 15726     This event occurs when the player on the done ...
# 15729     This event occurs when the player on the done ...
# 15731     This event occurs when the player on the done ...
# 15734     This event occurs when the player on the done ...
# 15736     This event occurs when the player on the done ...
# 15739     This event occurs when the player on the done ...
# 15741     This event occurs when the player on the done ...
# 15744     This event occurs when the player on the done ...
# 15746     This event occurs when the player on the done ...
# 15749     This event occurs when the player on the done ...
# 15751     This event occurs when the player on the done ...
# 15754     This event occurs when the player on the done ...
# ...                                                     ...
# 91820617  This event occurs when the player on the done ...
# 91820824  This event occurs when the player on the done ...
# 91821530  This event occurs when the player on the done ...
# 91821531  This event occurs when the player on the done ...
# 91821532  This event occurs when the player on the done ...
# 91821533  This event occurs when the player on the done ...
# 91821534  This event occurs when the player on the done ...
# 91821535  This event occurs when the player on the done ...
# 91821536  This event occurs when the player on the done ...
# 91821537  This event occurs when the player on the done ...
# 91821538  This event occurs when the player on the done ...
# 91821539  This event occurs when the player on the done ...
# 91821540  This event occurs when the player on the done ...
# 91821541  This event occurs when the player on the done ...
# 91821542  This event occurs when the player on the done ...
# 91821543  This event occurs when the player on the done ...
# 91821544  This event occurs when the player on the done ...
# 91821746  This event occurs when the player on the done ...
# 91821842  This event occurs when the player on the done ...
# 91821843  This event occurs when the player on the done ...
# 91821844  This event occurs when the player on the done ...
# 91821845  This event occurs when the player on the done ...
# 91821846  This event occurs when the player on the done ...
# 91821847  This event occurs when the player on the done ...
# 91821848  This event occurs when the player on the done ...
# 91821849  This event occurs when the player on the done ...
# 91821850  This event occurs when the player on the done ...
# 91821923  This event occurs when the player on the done ...
# 91821924  This event occurs when the player on the done ...
# 91821965  This event occurs when the player on the done ...
#
#                                                        args    game_session_y  \
# 11185     [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 11187     [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 11188     [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 11190     [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 11192     [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 11193     [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 11195     [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 11197     [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 11198     [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 11200     [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 11202     [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 11203     [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 15711     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15714     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15716     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15719     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15721     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15724     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15726     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15729     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15731     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15734     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15736     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15739     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15741     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15744     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15746     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15749     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# 15751     [{"name":"game_time","type":"int","info":"mill...  77b8ee947eb84b4e
# 15754     [{"name":"game_time","type":"int","info":"mill...  a9ef3ecb3d1acc6a
# ...                                                     ...               ...
# 91820617  [{"name":"game_time","type":"int","info":"mill...  89327730a963baf8
# 91820824  [{"name":"game_time","type":"int","info":"mill...  0963cf75a2c46eb2
# 91821530  [{"name":"game_time","type":"int","info":"mill...  be404f342567152a
# 91821531  [{"name":"game_time","type":"int","info":"mill...  d80626fa2dfc3d1a
# 91821532  [{"name":"game_time","type":"int","info":"mill...  e7742e2273276d2b
# 91821533  [{"name":"game_time","type":"int","info":"mill...  be404f342567152a
# 91821534  [{"name":"game_time","type":"int","info":"mill...  d80626fa2dfc3d1a
# 91821535  [{"name":"game_time","type":"int","info":"mill...  e7742e2273276d2b
# 91821536  [{"name":"game_time","type":"int","info":"mill...  be404f342567152a
# 91821537  [{"name":"game_time","type":"int","info":"mill...  d80626fa2dfc3d1a
# 91821538  [{"name":"game_time","type":"int","info":"mill...  e7742e2273276d2b
# 91821539  [{"name":"game_time","type":"int","info":"mill...  be404f342567152a
# 91821540  [{"name":"game_time","type":"int","info":"mill...  d80626fa2dfc3d1a
# 91821541  [{"name":"game_time","type":"int","info":"mill...  e7742e2273276d2b
# 91821542  [{"name":"game_time","type":"int","info":"mill...  be404f342567152a
# 91821543  [{"name":"game_time","type":"int","info":"mill...  d80626fa2dfc3d1a
# 91821544  [{"name":"game_time","type":"int","info":"mill...  e7742e2273276d2b
# 91821746  [{"name":"game_time","type":"int","info":"mill...  29d49201b23eaa0f
# 91821842  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821843  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821844  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821845  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821846  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821847  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821848  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821849  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821850  [{"name":"game_time","type":"int","info":"mill...  41f5106b9b6f1aee
# 91821923  [{"name":"game_time","type":"int","info":"mill...  bdaaa3f243a3663c
# 91821924  [{"name":"game_time","type":"int","info":"mill...  bdaaa3f243a3663c
# 91821965  [{"name":"game_time","type":"int","info":"mill...  c9a323ec3617fffc
#
#                                title_y  num_correct  num_incorrect  accuracy  \
# 11185     Mushroom Sorter (Assessment)            1              0  1.000000
# 11187     Mushroom Sorter (Assessment)            1              0  1.000000
# 11188     Mushroom Sorter (Assessment)            1              1  0.500000
# 11190     Mushroom Sorter (Assessment)            1              0  1.000000
# 11192     Mushroom Sorter (Assessment)            1              0  1.000000
# 11193     Mushroom Sorter (Assessment)            1              1  0.500000
# 11195     Mushroom Sorter (Assessment)            1              0  1.000000
# 11197     Mushroom Sorter (Assessment)            1              0  1.000000
# 11198     Mushroom Sorter (Assessment)            1              1  0.500000
# 11200     Mushroom Sorter (Assessment)            1              0  1.000000
# 11202     Mushroom Sorter (Assessment)            1              0  1.000000
# 11203     Mushroom Sorter (Assessment)            1              1  0.500000
# 15711       Bird Measurer (Assessment)            0             11  0.000000
# 15714       Bird Measurer (Assessment)            1              0  1.000000
# 15716       Bird Measurer (Assessment)            0             11  0.000000
# 15719       Bird Measurer (Assessment)            1              0  1.000000
# 15721       Bird Measurer (Assessment)            0             11  0.000000
# 15724       Bird Measurer (Assessment)            1              0  1.000000
# 15726       Bird Measurer (Assessment)            0             11  0.000000
# 15729       Bird Measurer (Assessment)            1              0  1.000000
# 15731       Bird Measurer (Assessment)            0             11  0.000000
# 15734       Bird Measurer (Assessment)            1              0  1.000000
# 15736       Bird Measurer (Assessment)            0             11  0.000000
# 15739       Bird Measurer (Assessment)            1              0  1.000000
# 15741       Bird Measurer (Assessment)            0             11  0.000000
# 15744       Bird Measurer (Assessment)            1              0  1.000000
# 15746       Bird Measurer (Assessment)            0             11  0.000000
# 15749       Bird Measurer (Assessment)            1              0  1.000000
# 15751       Bird Measurer (Assessment)            0             11  0.000000
# 15754       Bird Measurer (Assessment)            1              0  1.000000
# ...                                ...          ...            ...       ...
# 91820617     Chest Sorter (Assessment)            0              2  0.000000
# 91820824    Cart Balancer (Assessment)            1              0  1.000000
# 91821530     Chest Sorter (Assessment)            1              0  1.000000
# 91821531     Chest Sorter (Assessment)            1              1  0.500000
# 91821532     Chest Sorter (Assessment)            1              1  0.500000
# 91821533     Chest Sorter (Assessment)            1              0  1.000000
# 91821534     Chest Sorter (Assessment)            1              1  0.500000
# 91821535     Chest Sorter (Assessment)            1              1  0.500000
# 91821536     Chest Sorter (Assessment)            1              0  1.000000
# 91821537     Chest Sorter (Assessment)            1              1  0.500000
# 91821538     Chest Sorter (Assessment)            1              1  0.500000
# 91821539     Chest Sorter (Assessment)            1              0  1.000000
# 91821540     Chest Sorter (Assessment)            1              1  0.500000
# 91821541     Chest Sorter (Assessment)            1              1  0.500000
# 91821542     Chest Sorter (Assessment)            1              0  1.000000
# 91821543     Chest Sorter (Assessment)            1              1  0.500000
# 91821544     Chest Sorter (Assessment)            1              1  0.500000
# 91821746     Chest Sorter (Assessment)            1              0  1.000000
# 91821842     Chest Sorter (Assessment)            1              8  0.111111
# 91821843     Chest Sorter (Assessment)            1              8  0.111111
# 91821844     Chest Sorter (Assessment)            1              8  0.111111
# 91821845     Chest Sorter (Assessment)            1              8  0.111111
# 91821846     Chest Sorter (Assessment)            1              8  0.111111
# 91821847     Chest Sorter (Assessment)            1              8  0.111111
# 91821848     Chest Sorter (Assessment)            1              8  0.111111
# 91821849     Chest Sorter (Assessment)            1              8  0.111111
# 91821850     Chest Sorter (Assessment)            1              8  0.111111
# 91821923     Chest Sorter (Assessment)            0              2  0.000000
# 91821924     Chest Sorter (Assessment)            0              2  0.000000
# 91821965     Chest Sorter (Assessment)            1              0  1.000000
#
#           accuracy_group
# 11185                  3
# 11187                  3
# 11188                  2
# 11190                  3
# 11192                  3
# 11193                  2
# 11195                  3
# 11197                  3
# 11198                  2
# 11200                  3
# 11202                  3
# 11203                  2
# 15711                  0
# 15714                  3
# 15716                  0
# 15719                  3
# 15721                  0
# 15724                  3
# 15726                  0
# 15729                  3
# 15731                  0
# 15734                  3
# 15736                  0
# 15739                  3
# 15741                  0
# 15744                  3
# 15746                  0
# 15749                  3
# 15751                  0
# 15754                  3
# ...                  ...
# 91820617               0
# 91820824               3
# 91821530               3
# 91821531               2
# 91821532               2
# 91821533               3
# 91821534               2
# 91821535               2
# 91821536               3
# 91821537               2
# 91821538               2
# 91821539               3
# 91821540               2
# 91821541               2
# 91821542               3
# 91821543               2
# 91821544               2
# 91821746               3
# 91821842               1
# 91821843               1
# 91821844               1
# 91821845               1
# 91821846               1
# 91821847               1
# 91821848               1
# 91821849               1
# 91821850               1
# 91821923               0
# 91821924               0
# 91821965               3
#
# [180017 rows x 19 columns]

# %%
ffd_df[ffd_df['title_x']=='Cart Balancer (Assessment)']
# Out:
#           event_id    game_session_x                 timestamp  \
# 31109     d122731b  9480b026e3e7d371  2019-09-05T14:21:37.486Z
# 67359     d122731b  113a557b60770369  2019-08-08T00:04:38.875Z
# 78959     d122731b  3beae5a17e0b26f6  2019-09-26T13:49:46.536Z
# 78962     d122731b  3beae5a17e0b26f6  2019-09-26T13:49:46.536Z
# 78965     d122731b  0adc585fb4f48458  2019-09-26T13:50:27.648Z
# 78968     d122731b  0adc585fb4f48458  2019-09-26T13:50:27.648Z
# 82221     d122731b  440633fe3ef55b90  2019-10-09T20:39:40.134Z
# 83381     d122731b  a01b01d1e22d0446  2019-09-26T20:05:36.361Z
# 83382     d122731b  a01b01d1e22d0446  2019-09-26T20:05:36.361Z
# 83383     d122731b  900f3ed7ba1a3e72  2019-09-26T20:07:22.161Z
# 83384     d122731b  900f3ed7ba1a3e72  2019-09-26T20:07:22.161Z
# 104329    d122731b  8d95ce85370a27f1  2019-09-30T17:03:16.180Z
# 104330    d122731b  8d95ce85370a27f1  2019-09-30T17:03:16.180Z
# 104331    d122731b  8d95ce85370a27f1  2019-09-30T17:03:16.180Z
# 104332    d122731b  8d95ce85370a27f1  2019-09-30T17:03:16.180Z
# 104333    d122731b  8d95ce85370a27f1  2019-09-30T17:03:23.476Z
# 104334    d122731b  8d95ce85370a27f1  2019-09-30T17:03:23.476Z
# 104335    d122731b  8d95ce85370a27f1  2019-09-30T17:03:23.476Z
# 104336    d122731b  8d95ce85370a27f1  2019-09-30T17:03:23.476Z
# 104337    d122731b  8d95ce85370a27f1  2019-09-30T17:03:29.025Z
# 104338    d122731b  8d95ce85370a27f1  2019-09-30T17:03:29.025Z
# 104339    d122731b  8d95ce85370a27f1  2019-09-30T17:03:29.025Z
# 104340    d122731b  8d95ce85370a27f1  2019-09-30T17:03:29.025Z
# 104341    d122731b  8d95ce85370a27f1  2019-09-30T17:03:36.913Z
# 104342    d122731b  8d95ce85370a27f1  2019-09-30T17:03:36.913Z
# 104343    d122731b  8d95ce85370a27f1  2019-09-30T17:03:36.913Z
# 104344    d122731b  8d95ce85370a27f1  2019-09-30T17:03:36.913Z
# 104345    d122731b  8d95ce85370a27f1  2019-09-30T17:03:50.516Z
# 104346    d122731b  8d95ce85370a27f1  2019-09-30T17:03:50.516Z
# 104347    d122731b  8d95ce85370a27f1  2019-09-30T17:03:50.516Z
# ...            ...               ...                       ...
# 91751751  d122731b  86bc6380bcf6318a  2019-09-22T13:27:48.500Z
# 91751754  d122731b  0b2c8152e8a59f3e  2019-09-26T23:58:24.950Z
# 91751758  d122731b  0b2c8152e8a59f3e  2019-09-26T23:58:24.950Z
# 91785712  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:44.210Z
# 91785715  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:44.210Z
# 91785718  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:44.210Z
# 91785721  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:56.739Z
# 91785724  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:56.739Z
# 91785727  d122731b  f31a63e827e0b6c0  2019-08-14T19:46:56.739Z
# 91785730  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:05.490Z
# 91785733  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:05.490Z
# 91785736  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:05.490Z
# 91785739  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:12.657Z
# 91785742  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:12.657Z
# 91785745  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:12.657Z
# 91785748  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:23.542Z
# 91785751  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:23.542Z
# 91785754  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:23.542Z
# 91785757  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:28.943Z
# 91785760  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:28.943Z
# 91785763  d122731b  f31a63e827e0b6c0  2019-08-14T19:47:28.943Z
# 91785766  d122731b  91053d5451056830  2019-08-25T18:07:05.405Z
# 91785769  d122731b  91053d5451056830  2019-08-25T18:07:05.405Z
# 91785772  d122731b  91053d5451056830  2019-08-25T18:07:05.405Z
# 91785775  d122731b  4767c079c810f31b  2019-08-29T12:55:46.799Z
# 91785778  d122731b  4767c079c810f31b  2019-08-29T12:55:46.799Z
# 91785781  d122731b  4767c079c810f31b  2019-08-29T12:55:46.799Z
# 91799706  d122731b  14de9db5ad7dd503  2019-07-30T01:34:04.924Z
# 91814636  d122731b  9f8163b2e79cfb2d  2019-10-10T20:52:23.723Z
# 91820824  d122731b  0963cf75a2c46eb2  2019-10-10T12:11:38.397Z
#
#                                                  event_data installation_id  \
# 31109     {"correct":true,"left":[{"id":"gem07","weight"...        001d0ed0
# 67359     {"correct":true,"left":[{"id":"gem05","weight"...        002db7e3
# 78959     {"correct":true,"left":[{"id":"gem07","weight"...        003372b0
# 78962     {"correct":true,"left":[{"id":"gem07","weight"...        003372b0
# 78965     {"correct":true,"left":[{"id":"gem07","weight"...        003372b0
# 78968     {"correct":true,"left":[{"id":"gem07","weight"...        003372b0
# 82221     {"correct":true,"left":[{"id":"gem08","weight"...        00634433
# 83381     {"correct":true,"left":[{"id":"gem07","weight"...        00667b88
# 83382     {"correct":true,"left":[{"id":"gem07","weight"...        00667b88
# 83383     {"correct":false,"left":[],"right":[{"id":"gem...        00667b88
# 83384     {"correct":false,"left":[],"right":[{"id":"gem...        00667b88
# 104329    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104330    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104331    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104332    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104333    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104334    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104335    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104336    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104337    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104338    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104339    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104340    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104341    {"correct":false,"left":[],"right":[{"id":"gem...        00a0dbeb
# 104342    {"correct":false,"left":[],"right":[{"id":"gem...        00a0dbeb
# 104343    {"correct":false,"left":[],"right":[{"id":"gem...        00a0dbeb
# 104344    {"correct":false,"left":[],"right":[{"id":"gem...        00a0dbeb
# 104345    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104346    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# 104347    {"correct":false,"left":[{"id":"gem06","weight...        00a0dbeb
# ...                                                     ...             ...
# 91751751  {"correct":true,"left":[{"id":"gem05","weight"...        ff90db99
# 91751754  {"correct":true,"left":[{"id":"gem05","weight"...        ff90db99
# 91751758  {"correct":true,"left":[{"id":"gem05","weight"...        ff90db99
# 91785712  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785715  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785718  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785721  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785724  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785727  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785730  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785733  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785736  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785739  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785742  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785745  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785748  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785751  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785754  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785757  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785760  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785763  {"correct":false,"left":[{"id":"gem01","weight...        ff9715db
# 91785766  {"correct":true,"left":[{"id":"gem07","weight"...        ff9715db
# 91785769  {"correct":true,"left":[{"id":"gem07","weight"...        ff9715db
# 91785772  {"correct":true,"left":[{"id":"gem07","weight"...        ff9715db
# 91785775  {"correct":true,"left":[{"id":"gem05","weight"...        ff9715db
# 91785778  {"correct":true,"left":[{"id":"gem05","weight"...        ff9715db
# 91785781  {"correct":true,"left":[{"id":"gem05","weight"...        ff9715db
# 91799706  {"correct":true,"left":[{"id":"gem07","weight"...        ffc90c32
# 91814636  {"correct":true,"left":[{"id":"gem07","weight"...        57ee528d
# 91820824  {"correct":true,"left":[{"id":"gem07","weight"...        c7fcf68c
#
#           event_count  event_code  game_time                     title_x  \
# 31109               9        4100      13811  Cart Balancer (Assessment)
# 67359              31        4100      35108  Cart Balancer (Assessment)
# 78959              25        4100      22643  Cart Balancer (Assessment)
# 78962              25        4100      22643  Cart Balancer (Assessment)
# 78965              29        4100      20734  Cart Balancer (Assessment)
# 78968              29        4100      20734  Cart Balancer (Assessment)
# 82221              23        4100      23190  Cart Balancer (Assessment)
# 83381              46        4100      59191  Cart Balancer (Assessment)
# 83382              46        4100      59191  Cart Balancer (Assessment)
# 83383              75        4100      87756  Cart Balancer (Assessment)
# 83384              75        4100      87756  Cart Balancer (Assessment)
# 104329             27        4100      21613  Cart Balancer (Assessment)
# 104330             27        4100      21613  Cart Balancer (Assessment)
# 104331             27        4100      21613  Cart Balancer (Assessment)
# 104332             27        4100      21613  Cart Balancer (Assessment)
# 104333             34        4100      28913  Cart Balancer (Assessment)
# 104334             34        4100      28913  Cart Balancer (Assessment)
# 104335             34        4100      28913  Cart Balancer (Assessment)
# 104336             34        4100      28913  Cart Balancer (Assessment)
# 104337             38        4100      34464  Cart Balancer (Assessment)
# 104338             38        4100      34464  Cart Balancer (Assessment)
# 104339             38        4100      34464  Cart Balancer (Assessment)
# 104340             38        4100      34464  Cart Balancer (Assessment)
# 104341             47        4100      42347  Cart Balancer (Assessment)
# 104342             47        4100      42347  Cart Balancer (Assessment)
# 104343             47        4100      42347  Cart Balancer (Assessment)
# 104344             47        4100      42347  Cart Balancer (Assessment)
# 104345             58        4100      55948  Cart Balancer (Assessment)
# 104346             58        4100      55948  Cart Balancer (Assessment)
# 104347             58        4100      55948  Cart Balancer (Assessment)
# ...               ...         ...        ...                         ...
# 91751751           25        4100      22809  Cart Balancer (Assessment)
# 91751754           29        4100      25858  Cart Balancer (Assessment)
# 91751758           29        4100      25858  Cart Balancer (Assessment)
# 91785712           46        4100      57000  Cart Balancer (Assessment)
# 91785715           46        4100      57000  Cart Balancer (Assessment)
# 91785718           46        4100      57000  Cart Balancer (Assessment)
# 91785721           55        4100      69534  Cart Balancer (Assessment)
# 91785724           55        4100      69534  Cart Balancer (Assessment)
# 91785727           55        4100      69534  Cart Balancer (Assessment)
# 91785730           60        4100      78285  Cart Balancer (Assessment)
# 91785733           60        4100      78285  Cart Balancer (Assessment)
# 91785736           60        4100      78285  Cart Balancer (Assessment)
# 91785739           65        4100      85452  Cart Balancer (Assessment)
# 91785742           65        4100      85452  Cart Balancer (Assessment)
# 91785745           65        4100      85452  Cart Balancer (Assessment)
# 91785748           71        4100      96336  Cart Balancer (Assessment)
# 91785751           71        4100      96336  Cart Balancer (Assessment)
# 91785754           71        4100      96336  Cart Balancer (Assessment)
# 91785757           74        4100     101736  Cart Balancer (Assessment)
# 91785760           74        4100     101736  Cart Balancer (Assessment)
# 91785763           74        4100     101736  Cart Balancer (Assessment)
# 91785766           11        4100      10537  Cart Balancer (Assessment)
# 91785769           11        4100      10537  Cart Balancer (Assessment)
# 91785772           11        4100      10537  Cart Balancer (Assessment)
# 91785775           24        4100      21091  Cart Balancer (Assessment)
# 91785778           24        4100      21091  Cart Balancer (Assessment)
# 91785781           24        4100      21091  Cart Balancer (Assessment)
# 91799706           29        4100      21571  Cart Balancer (Assessment)
# 91814636           49        4100      26251  Cart Balancer (Assessment)
# 91820824           23        4100      19897  Cart Balancer (Assessment)
#
#                 type         world  \
# 31109     Assessment  CRYSTALCAVES
# 67359     Assessment  CRYSTALCAVES
# 78959     Assessment  CRYSTALCAVES
# 78962     Assessment  CRYSTALCAVES
# 78965     Assessment  CRYSTALCAVES
# 78968     Assessment  CRYSTALCAVES
# 82221     Assessment  CRYSTALCAVES
# 83381     Assessment  CRYSTALCAVES
# 83382     Assessment  CRYSTALCAVES
# 83383     Assessment  CRYSTALCAVES
# 83384     Assessment  CRYSTALCAVES
# 104329    Assessment  CRYSTALCAVES
# 104330    Assessment  CRYSTALCAVES
# 104331    Assessment  CRYSTALCAVES
# 104332    Assessment  CRYSTALCAVES
# 104333    Assessment  CRYSTALCAVES
# 104334    Assessment  CRYSTALCAVES
# 104335    Assessment  CRYSTALCAVES
# 104336    Assessment  CRYSTALCAVES
# 104337    Assessment  CRYSTALCAVES
# 104338    Assessment  CRYSTALCAVES
# 104339    Assessment  CRYSTALCAVES
# 104340    Assessment  CRYSTALCAVES
# 104341    Assessment  CRYSTALCAVES
# 104342    Assessment  CRYSTALCAVES
# 104343    Assessment  CRYSTALCAVES
# 104344    Assessment  CRYSTALCAVES
# 104345    Assessment  CRYSTALCAVES
# 104346    Assessment  CRYSTALCAVES
# 104347    Assessment  CRYSTALCAVES
# ...              ...           ...
# 91751751  Assessment  CRYSTALCAVES
# 91751754  Assessment  CRYSTALCAVES
# 91751758  Assessment  CRYSTALCAVES
# 91785712  Assessment  CRYSTALCAVES
# 91785715  Assessment  CRYSTALCAVES
# 91785718  Assessment  CRYSTALCAVES
# 91785721  Assessment  CRYSTALCAVES
# 91785724  Assessment  CRYSTALCAVES
# 91785727  Assessment  CRYSTALCAVES
# 91785730  Assessment  CRYSTALCAVES
# 91785733  Assessment  CRYSTALCAVES
# 91785736  Assessment  CRYSTALCAVES
# 91785739  Assessment  CRYSTALCAVES
# 91785742  Assessment  CRYSTALCAVES
# 91785745  Assessment  CRYSTALCAVES
# 91785748  Assessment  CRYSTALCAVES
# 91785751  Assessment  CRYSTALCAVES
# 91785754  Assessment  CRYSTALCAVES
# 91785757  Assessment  CRYSTALCAVES
# 91785760  Assessment  CRYSTALCAVES
# 91785763  Assessment  CRYSTALCAVES
# 91785766  Assessment  CRYSTALCAVES
# 91785769  Assessment  CRYSTALCAVES
# 91785772  Assessment  CRYSTALCAVES
# 91785775  Assessment  CRYSTALCAVES
# 91785778  Assessment  CRYSTALCAVES
# 91785781  Assessment  CRYSTALCAVES
# 91799706  Assessment  CRYSTALCAVES
# 91814636  Assessment  CRYSTALCAVES
# 91820824  Assessment  CRYSTALCAVES
#
#                                                        info  \
# 31109     This event occurs when the player on the done ...
# 67359     This event occurs when the player on the done ...
# 78959     This event occurs when the player on the done ...
# 78962     This event occurs when the player on the done ...
# 78965     This event occurs when the player on the done ...
# 78968     This event occurs when the player on the done ...
# 82221     This event occurs when the player on the done ...
# 83381     This event occurs when the player on the done ...
# 83382     This event occurs when the player on the done ...
# 83383     This event occurs when the player on the done ...
# 83384     This event occurs when the player on the done ...
# 104329    This event occurs when the player on the done ...
# 104330    This event occurs when the player on the done ...
# 104331    This event occurs when the player on the done ...
# 104332    This event occurs when the player on the done ...
# 104333    This event occurs when the player on the done ...
# 104334    This event occurs when the player on the done ...
# 104335    This event occurs when the player on the done ...
# 104336    This event occurs when the player on the done ...
# 104337    This event occurs when the player on the done ...
# 104338    This event occurs when the player on the done ...
# 104339    This event occurs when the player on the done ...
# 104340    This event occurs when the player on the done ...
# 104341    This event occurs when the player on the done ...
# 104342    This event occurs when the player on the done ...
# 104343    This event occurs when the player on the done ...
# 104344    This event occurs when the player on the done ...
# 104345    This event occurs when the player on the done ...
# 104346    This event occurs when the player on the done ...
# 104347    This event occurs when the player on the done ...
# ...                                                     ...
# 91751751  This event occurs when the player on the done ...
# 91751754  This event occurs when the player on the done ...
# 91751758  This event occurs when the player on the done ...
# 91785712  This event occurs when the player on the done ...
# 91785715  This event occurs when the player on the done ...
# 91785718  This event occurs when the player on the done ...
# 91785721  This event occurs when the player on the done ...
# 91785724  This event occurs when the player on the done ...
# 91785727  This event occurs when the player on the done ...
# 91785730  This event occurs when the player on the done ...
# 91785733  This event occurs when the player on the done ...
# 91785736  This event occurs when the player on the done ...
# 91785739  This event occurs when the player on the done ...
# 91785742  This event occurs when the player on the done ...
# 91785745  This event occurs when the player on the done ...
# 91785748  This event occurs when the player on the done ...
# 91785751  This event occurs when the player on the done ...
# 91785754  This event occurs when the player on the done ...
# 91785757  This event occurs when the player on the done ...
# 91785760  This event occurs when the player on the done ...
# 91785763  This event occurs when the player on the done ...
# 91785766  This event occurs when the player on the done ...
# 91785769  This event occurs when the player on the done ...
# 91785772  This event occurs when the player on the done ...
# 91785775  This event occurs when the player on the done ...
# 91785778  This event occurs when the player on the done ...
# 91785781  This event occurs when the player on the done ...
# 91799706  This event occurs when the player on the done ...
# 91814636  This event occurs when the player on the done ...
# 91820824  This event occurs when the player on the done ...
#
#                                                        args    game_session_y  \
# 31109     [{"name":"game_time","type":"int","info":"mill...  9480b026e3e7d371
# 67359     [{"name":"game_time","type":"int","info":"mill...  113a557b60770369
# 78959     [{"name":"game_time","type":"int","info":"mill...  0adc585fb4f48458
# 78962     [{"name":"game_time","type":"int","info":"mill...  3beae5a17e0b26f6
# 78965     [{"name":"game_time","type":"int","info":"mill...  0adc585fb4f48458
# 78968     [{"name":"game_time","type":"int","info":"mill...  3beae5a17e0b26f6
# 82221     [{"name":"game_time","type":"int","info":"mill...  440633fe3ef55b90
# 83381     [{"name":"game_time","type":"int","info":"mill...  900f3ed7ba1a3e72
# 83382     [{"name":"game_time","type":"int","info":"mill...  a01b01d1e22d0446
# 83383     [{"name":"game_time","type":"int","info":"mill...  900f3ed7ba1a3e72
# 83384     [{"name":"game_time","type":"int","info":"mill...  a01b01d1e22d0446
# 104329    [{"name":"game_time","type":"int","info":"mill...  13ef4c0f43016c21
# 104330    [{"name":"game_time","type":"int","info":"mill...  8d95ce85370a27f1
# 104331    [{"name":"game_time","type":"int","info":"mill...  9debd3d366d92441
# 104332    [{"name":"game_time","type":"int","info":"mill...  a77bfd165bda7f8f
# 104333    [{"name":"game_time","type":"int","info":"mill...  13ef4c0f43016c21
# 104334    [{"name":"game_time","type":"int","info":"mill...  8d95ce85370a27f1
# 104335    [{"name":"game_time","type":"int","info":"mill...  9debd3d366d92441
# 104336    [{"name":"game_time","type":"int","info":"mill...  a77bfd165bda7f8f
# 104337    [{"name":"game_time","type":"int","info":"mill...  13ef4c0f43016c21
# 104338    [{"name":"game_time","type":"int","info":"mill...  8d95ce85370a27f1
# 104339    [{"name":"game_time","type":"int","info":"mill...  9debd3d366d92441
# 104340    [{"name":"game_time","type":"int","info":"mill...  a77bfd165bda7f8f
# 104341    [{"name":"game_time","type":"int","info":"mill...  13ef4c0f43016c21
# 104342    [{"name":"game_time","type":"int","info":"mill...  8d95ce85370a27f1
# 104343    [{"name":"game_time","type":"int","info":"mill...  9debd3d366d92441
# 104344    [{"name":"game_time","type":"int","info":"mill...  a77bfd165bda7f8f
# 104345    [{"name":"game_time","type":"int","info":"mill...  13ef4c0f43016c21
# 104346    [{"name":"game_time","type":"int","info":"mill...  8d95ce85370a27f1
# 104347    [{"name":"game_time","type":"int","info":"mill...  9debd3d366d92441
# ...                                                     ...               ...
# 91751751  [{"name":"game_time","type":"int","info":"mill...  86bc6380bcf6318a
# 91751754  [{"name":"game_time","type":"int","info":"mill...  0b2c8152e8a59f3e
# 91751758  [{"name":"game_time","type":"int","info":"mill...  86bc6380bcf6318a
# 91785712  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785715  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785718  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785721  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785724  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785727  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785730  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785733  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785736  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785739  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785742  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785745  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785748  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785751  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785754  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785757  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785760  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785763  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785766  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785769  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785772  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91785775  [{"name":"game_time","type":"int","info":"mill...  4767c079c810f31b
# 91785778  [{"name":"game_time","type":"int","info":"mill...  91053d5451056830
# 91785781  [{"name":"game_time","type":"int","info":"mill...  f31a63e827e0b6c0
# 91799706  [{"name":"game_time","type":"int","info":"mill...  14de9db5ad7dd503
# 91814636  [{"name":"game_time","type":"int","info":"mill...  9f8163b2e79cfb2d
# 91820824  [{"name":"game_time","type":"int","info":"mill...  0963cf75a2c46eb2
#
#                              title_y  num_correct  num_incorrect  accuracy  \
# 31109     Cart Balancer (Assessment)            1              0       1.0
# 67359     Cart Balancer (Assessment)            1              0       1.0
# 78959     Cart Balancer (Assessment)            1              0       1.0
# 78962     Cart Balancer (Assessment)            1              0       1.0
# 78965     Cart Balancer (Assessment)            1              0       1.0
# 78968     Cart Balancer (Assessment)            1              0       1.0
# 82221     Cart Balancer (Assessment)            1              0       1.0
# 83381     Cart Balancer (Assessment)            0              1       0.0
# 83382     Cart Balancer (Assessment)            1              0       1.0
# 83383     Cart Balancer (Assessment)            0              1       0.0
# 83384     Cart Balancer (Assessment)            1              0       1.0
# 104329    Cart Balancer (Assessment)            0              3       0.0
# 104330    Cart Balancer (Assessment)            0              6       0.0
# 104331    Cart Balancer (Assessment)            0              1       0.0
# 104332    Cart Balancer (Assessment)            0              2       0.0
# 104333    Cart Balancer (Assessment)            0              3       0.0
# 104334    Cart Balancer (Assessment)            0              6       0.0
# 104335    Cart Balancer (Assessment)            0              1       0.0
# 104336    Cart Balancer (Assessment)            0              2       0.0
# 104337    Cart Balancer (Assessment)            0              3       0.0
# 104338    Cart Balancer (Assessment)            0              6       0.0
# 104339    Cart Balancer (Assessment)            0              1       0.0
# 104340    Cart Balancer (Assessment)            0              2       0.0
# 104341    Cart Balancer (Assessment)            0              3       0.0
# 104342    Cart Balancer (Assessment)            0              6       0.0
# 104343    Cart Balancer (Assessment)            0              1       0.0
# 104344    Cart Balancer (Assessment)            0              2       0.0
# 104345    Cart Balancer (Assessment)            0              3       0.0
# 104346    Cart Balancer (Assessment)            0              6       0.0
# 104347    Cart Balancer (Assessment)            0              1       0.0
# ...                              ...          ...            ...       ...
# 91751751  Cart Balancer (Assessment)            1              0       1.0
# 91751754  Cart Balancer (Assessment)            1              0       1.0
# 91751758  Cart Balancer (Assessment)            1              0       1.0
# 91785712  Cart Balancer (Assessment)            1              0       1.0
# 91785715  Cart Balancer (Assessment)            1              0       1.0
# 91785718  Cart Balancer (Assessment)            0              6       0.0
# 91785721  Cart Balancer (Assessment)            1              0       1.0
# 91785724  Cart Balancer (Assessment)            1              0       1.0
# 91785727  Cart Balancer (Assessment)            0              6       0.0
# 91785730  Cart Balancer (Assessment)            1              0       1.0
# 91785733  Cart Balancer (Assessment)            1              0       1.0
# 91785736  Cart Balancer (Assessment)            0              6       0.0
# 91785739  Cart Balancer (Assessment)            1              0       1.0
# 91785742  Cart Balancer (Assessment)            1              0       1.0
# 91785745  Cart Balancer (Assessment)            0              6       0.0
# 91785748  Cart Balancer (Assessment)            1              0       1.0
# 91785751  Cart Balancer (Assessment)            1              0       1.0
# 91785754  Cart Balancer (Assessment)            0              6       0.0
# 91785757  Cart Balancer (Assessment)            1              0       1.0
# 91785760  Cart Balancer (Assessment)            1              0       1.0
# 91785763  Cart Balancer (Assessment)            0              6       0.0
# 91785766  Cart Balancer (Assessment)            1              0       1.0
# 91785769  Cart Balancer (Assessment)            1              0       1.0
# 91785772  Cart Balancer (Assessment)            0              6       0.0
# 91785775  Cart Balancer (Assessment)            1              0       1.0
# 91785778  Cart Balancer (Assessment)            1              0       1.0
# 91785781  Cart Balancer (Assessment)            0              6       0.0
# 91799706  Cart Balancer (Assessment)            1              0       1.0
# 91814636  Cart Balancer (Assessment)            1              0       1.0
# 91820824  Cart Balancer (Assessment)            1              0       1.0
#
#           accuracy_group
# 31109                  3
# 67359                  3
# 78959                  3
# 78962                  3
# 78965                  3
# 78968                  3
# 82221                  3
# 83381                  0
# 83382                  3
# 83383                  0
# 83384                  3
# 104329                 0
# 104330                 0
# 104331                 0
# 104332                 0
# 104333                 0
# 104334                 0
# 104335                 0
# 104336                 0
# 104337                 0
# 104338                 0
# 104339                 0
# 104340                 0
# 104341                 0
# 104342                 0
# 104343                 0
# 104344                 0
# 104345                 0
# 104346                 0
# 104347                 0
# ...                  ...
# 91751751               3
# 91751754               3
# 91751758               3
# 91785712               3
# 91785715               3
# 91785718               0
# 91785721               3
# 91785724               3
# 91785727               0
# 91785730               3
# 91785733               3
# 91785736               0
# 91785739               3
# 91785742               3
# 91785745               0
# 91785748               3
# 91785751               3
# 91785754               0
# 91785757               3
# 91785760               3
# 91785763               0
# 91785766               3
# 91785769               3
# 91785772               0
# 91785775               3
# 91785778               3
# 91785781               0
# 91799706               3
# 91814636               3
# 91820824               3
#
# [24749 rows x 19 columns]

# %%
import jsonf
extracted_event_data = pd.io.json.json_normalize(fd_df.event_data.apply(json.loads))

# %%
extracted_event_data.columns
# Out:
# Index(['buckets', 'buckets_placed', 'caterpillars', 'correct', 'duration',
#        'event_code', 'event_count', 'game_time', 'hats', 'left', 'pillars',
#        'right', 'stumps'],
#       dtype='object')

# %%
extracted_event_data.head()
# Out:
#   buckets buckets_placed caterpillars  correct  duration  event_code  \
# 0     NaN            NaN          NaN     True       NaN        4100
# 1     NaN            NaN          NaN     True       NaN        4100
# 2     NaN            NaN          NaN     True       NaN        4100
# 3     NaN            NaN          NaN     True       NaN        4100
# 4     NaN            NaN          NaN     True       NaN        4100
#
#    event_count  game_time hats left pillars right     stumps
# 0           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 1           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 2           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 3           30      18026  NaN  NaN     NaN   NaN  [1, 2, 4]
# 4           30      18026  NaN  NaN     NaN   NaN  [1, 2, 4]

# %%
extracted_event_data['buckets_placed'].value_counts()
# Out:
# [3, 1, 2]    15428
# [0, 0, 0]     7656
# [2, 1, 3]     5395
# [1, 2, 3]     2787
# [2, 3, 1]     2741
# [3, 2, 1]     2663
# [1, 3, 2]     1258
# [3, 1, 0]      534
# [0, 1, 0]      513
# [3, 0, 0]      400
# [2, 0, 0]      382
# [3, 2, 0]      379
# [2, 1, 0]      257
# [0, 1, 2]      188
# [0, 3, 0]      172
# [3, 0, 2]      100
# [1, 3, 0]       78
# [0, 2, 0]       73
# [0, 0, 2]       63
# [0, 0, 3]       60
# [0, 0, 1]       55
# [1, 0, 0]       52
# [0, 1, 3]       49
# [2, 0, 1]       17
# [0, 2, 3]       17
# [3, 0, 1]       13
# [0, 3, 2]       12
# [0, 2, 1]       11
# [0, 3, 1]        9
# [1, 2, 0]        9
# [2, 3, 0]        6
# [2, 0, 3]        6
# [1, 0, 2]        4
# [1, 0, 3]        1
# Name: buckets_placed, dtype: int64

# %%
#seperate based on type, this is how we will divide the attributes and receive the results
#To receive them each group will have to be analzed seperately 
#ignore specific attributes of the games and the overalapping attributes each can be generalized

# %%
filtered_df=full_tandt[(full_tandt['event_code']==4100) | (full_tandt['event_code']==4110)]

# %%
filtered_df.shape

# %%
filtered_df.head()

# %%
import json
extracted_event_data = pd.io.json.json_normalize(filtered_df.event_data.apply(json.loads))

# %%
extracted_event_data
