# %%
import pandas as pd
import numpy as np
import json

# %%
# Replace path with path to your train.csv and train_labels.csv
train = pd.read_csv('../DSB_DF/train.csv')
train_labels = pd.read_csv('../DSB_DF/train_labels.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11341042 entries, 0 to 11341041
# Data columns (total 11 columns):
# event_id           object
# game_session       object
# timestamp          object
# event_data         object
# installation_id    object
# event_count        int64
# event_code         int64
# game_time          int64
# title              object
# type               object
# world              object
# dtypes: int64(3), object(8)
# memory usage: 951.8+ MB

# %%
from pandas.io.json import json_normalize
#json_normalize(train['event_data'].iloc[0:7].apply(json.loads))
event_data_df = json_normalize(train['event_data'].apply(json.loads))

# %%
event_data_df.head()
# Out:
#    event_code  event_count version  game_time  \
# 0        2000            1     NaN        NaN
# 1        2000            1     NaN        NaN
# 2        2000            1     1.0        0.0
# 3        3010            2     NaN       53.0
# 4        3110            3     NaN     6972.0
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Let's build a sandcastle! First, fill up your ...
# 4  Let's build a sandcastle! First, fill up your ...
#
#                                       identifier media_type  total_duration  \
# 0                                            NaN        NaN             NaN
# 1                                            NaN        NaN             NaN
# 2                                            NaN        NaN             NaN
# 3  Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape      audio          6758.0
# 4  Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape      audio             NaN
#
#    duration  coordinates.x  ...  nest  pillars  max_position end_position  \
# 0       NaN            NaN  ...   NaN      NaN           NaN          NaN
# 1       NaN            NaN  ...   NaN      NaN           NaN          NaN
# 2       NaN            NaN  ...   NaN      NaN           NaN          NaN
# 3       NaN            NaN  ...   NaN      NaN           NaN          NaN
# 4    6919.0            NaN  ...   NaN      NaN           NaN          NaN
#
#   gate.row  gate.column  gate.side dinosaur_weight  dinosaur_count  chests
# 0      NaN          NaN        NaN             NaN             NaN     NaN
# 1      NaN          NaN        NaN             NaN             NaN     NaN
# 2      NaN          NaN        NaN             NaN             NaN     NaN
# 3      NaN          NaN        NaN             NaN             NaN     NaN
# 4      NaN          NaN        NaN             NaN             NaN     NaN
#
# [5 rows x 136 columns]

# %%
[event_data_df.columns]
