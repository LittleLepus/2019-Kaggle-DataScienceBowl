# %%
import pandas as pd

# %%
df1=pd.read_csv('train.csv')

# %%
df1.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
filtered_df=df1[(df1['title']=='Cart Balancer (Assessment)') | (df1['title']=='Cauldron Filler (Assessment)') | (df1['title']=='Mushroom Sorter (Assessment)') | (df1['title']=='Chest Sorter (Assessment)') | (df1['title']=='Bird Measurer (Assessment)')]

# %%
filtered_df.shape
# Out:
# (925345, 11)

# %%
df2=pd.read_csv('train_labels.csv')

# %%
df2.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
filtered_df['title'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    199595
# Chest Sorter (Assessment)       190318
# Bird Measurer (Assessment)      190164
# Cauldron Filler (Assessment)    181925
# Cart Balancer (Assessment)      163343
# Name: title, dtype: int64

# %%
df3=pd.read_csv('specs.csv')

# %%
first_m=pd.merge(filtered_df,df3,on='event_id')

# %%
df2['title'].value_counts()
# Out:
# Cart Balancer (Assessment)      4151
# Cauldron Filler (Assessment)    4055
# Mushroom Sorter (Assessment)    3757
# Chest Sorter (Assessment)       2981
# Bird Measurer (Assessment)      2746
# Name: title, dtype: int64

# %%
df3.head()
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
first_m=pd.merge(df1,df3,on='event_id')

# %%
first_m.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  27253bdc  091587ed87b9637c  2019-09-06T18:10:51.183Z
# 3  27253bdc  3fce4f09769ff0b7  2019-09-06T18:18:11.250Z
# 4  27253bdc  04168b61c0650977  2019-09-06T18:18:42.392Z
#
#                                event_data installation_id  event_count  \
# 0  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 1  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 2  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 3  {"event_code": 2000, "event_count": 1}        0001e90f            1
# 4  {"event_code": 2000, "event_count": 1}        0001e90f            1
#
#    event_code  game_time                    title  type        world  \
# 0        2000          0  Welcome to Lost Lagoon!  Clip         NONE
# 1        2000          0     Magma Peak - Level 1  Clip    MAGMAPEAK
# 2        2000          0     Magma Peak - Level 2  Clip    MAGMAPEAK
# 3        2000          0  Tree Top City - Level 1  Clip  TREETOPCITY
# 4        2000          0         Ordering Spheres  Clip  TREETOPCITY
#
#                                                 info  \
# 0  This event is triggered when a video starts pl...
# 1  This event is triggered when a video starts pl...
# 2  This event is triggered when a video starts pl...
# 3  This event is triggered when a video starts pl...
# 4  This event is triggered when a video starts pl...
#
#                                                 args
# 0  [{"name":"event_count","type":"int","info":"se...
# 1  [{"name":"event_count","type":"int","info":"se...
# 2  [{"name":"event_count","type":"int","info":"se...
# 3  [{"name":"event_count","type":"int","info":"se...
# 4  [{"name":"event_count","type":"int","info":"se...

# %%
full_tandt=pd.merge(first_m,df2,on='installation_id')

# %%
full_tandt.head()
# Out:
#    event_id    game_session_x                 timestamp  \
# 0  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 1  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 2  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 3  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
# 4  27253bdc  34ba1a28d02ba8ba  2019-08-06T04:57:18.904Z
#
#                                event_data installation_id  event_count  \
# 0  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 1  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 2  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 3  {"event_code": 2000, "event_count": 1}        0006a69f            1
# 4  {"event_code": 2000, "event_count": 1}        0006a69f            1
#
#    event_code  game_time                  title_x  type world  \
# 0        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 1        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 2        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 3        2000          0  Welcome to Lost Lagoon!  Clip  NONE
# 4        2000          0  Welcome to Lost Lagoon!  Clip  NONE
#
#                                                 info  \
# 0  This event is triggered when a video starts pl...
# 1  This event is triggered when a video starts pl...
# 2  This event is triggered when a video starts pl...
# 3  This event is triggered when a video starts pl...
# 4  This event is triggered when a video starts pl...
#
#                                                 args    game_session_y  \
# 0  [{"name":"event_count","type":"int","info":"se...  6bdf9623adc94d89
# 1  [{"name":"event_count","type":"int","info":"se...  77b8ee947eb84b4e
# 2  [{"name":"event_count","type":"int","info":"se...  901acc108f55a5a1
# 3  [{"name":"event_count","type":"int","info":"se...  9501794defd84e4d
# 4  [{"name":"event_count","type":"int","info":"se...  a9ef3ecb3d1acc6a
#
#                         title_y  num_correct  num_incorrect  accuracy  \
# 0  Mushroom Sorter (Assessment)            1              0       1.0
# 1    Bird Measurer (Assessment)            0             11       0.0
# 2  Mushroom Sorter (Assessment)            1              0       1.0
# 3  Mushroom Sorter (Assessment)            1              1       0.5
# 4    Bird Measurer (Assessment)            1              0       1.0
#
#    accuracy_group
# 0               3
# 1               0
# 2               3
# 3               2
# 4               3

# %%
final_filter_df=full_tandt[(full_tandt['title_x']==full_tandt['title_y'])]

# %%
final_filter_df.shape
# Out:
# (3377485, 19)

# %%
final_filter_df['title_x'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    850557
# Cauldron Filler (Assessment)    826553
# Bird Measurer (Assessment)      585632
# Chest Sorter (Assessment)       563505
# Cart Balancer (Assessment)      551238
# Name: title_x, dtype: int64

# %%
final_filter_df['title_y'].value_counts()
# Out:
# Mushroom Sorter (Assessment)    850557
# Cauldron Filler (Assessment)    826553
# Bird Measurer (Assessment)      585632
# Chest Sorter (Assessment)       563505
# Cart Balancer (Assessment)      551238
# Name: title_y, dtype: int64

# %%
full_tandt['title_x'].value_counts()
# Out:
# Scrub-A-Dub                      8194412
# Bottle Filler (Activity)         6764681
# Chow Time                        5745828
# Sandcastle Builder (Activity)    5315848
# Crystals Rule                    4909354
# Bug Measurer (Activity)          4396723
# Fireworks (Activity)             4268736
# Bubble Bath                      4157600
# Pan Balance                      4149101
# Dino Drink                       3416337
# Dino Dive                        3407653
# Happy Camel                      3330595
# Chicken Balancer (Activity)      3233470
# Air Show                         3205929
# Flower Waterer (Activity)        3177810
# All Star Sorting                 3052537
# Mushroom Sorter (Assessment)     2914510
# Cauldron Filler (Assessment)     2796730
# Bird Measurer (Assessment)       2714330
# Chest Sorter (Assessment)        2570481
# Watering Hole (Activity)         2511416
# Leaf Leader                      2354373
# Egg Dropper (Activity)           2181664
# Cart Balancer (Assessment)       1941801
# Magma Peak - Level 2               91856
# Crystal Caves - Level 2            83754
# Tree Top City - Level 2            82688
# Crystal Caves - Level 3            79786
# Welcome to Lost Lagoon!            75155
# Tree Top City - Level 3            71614
# Ordering Spheres                   67589
# Slop Problem                       53372
# Pirate's Tale                      51264
# Magma Peak - Level 1               49627
# 12 Monkeys                         49045
# Tree Top City - Level 1            48490
# Treasure Map                       47655
# Crystal Caves - Level 1            46906
# Balancing Act                      39155
# Lifting Heavy Things               39070
# Costume Box                        37737
# Honey Cake                         32235
# Heavy, Heavier, Heaviest           31842
# Rulers                             31210
# Name: title_x, dtype: int64

# %%
full_tandt['title_y'].value_counts()
# Out:
# Cauldron Filler (Assessment)    21220604
# Mushroom Sorter (Assessment)    20506353
# Cart Balancer (Assessment)      19764464
# Bird Measurer (Assessment)      15370714
# Chest Sorter (Assessment)       14959834
# Name: title_y, dtype: int64

# %%
full_tandt['type'].value_counts()
# Out:
# Game          45923719
# Activity      31850348
# Assessment    12937852
# Clip           1110050
# Name: type, dtype: int64

# %%
final_filter_df.head()
# Out:
#        event_id    game_session_x                 timestamp  \
# 10535  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10537  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10538  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 10540  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
# 10542  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
#
#                                               event_data installation_id  \
# 10535  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10537  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10538  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10540  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 10542  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
#
#        event_count  event_code  game_time                       title_x  \
# 10535            1        2000          0  Mushroom Sorter (Assessment)
# 10537            1        2000          0  Mushroom Sorter (Assessment)
# 10538            1        2000          0  Mushroom Sorter (Assessment)
# 10540            1        2000          0  Mushroom Sorter (Assessment)
# 10542            1        2000          0  Mushroom Sorter (Assessment)
#
#              type        world  \
# 10535  Assessment  TREETOPCITY
# 10537  Assessment  TREETOPCITY
# 10538  Assessment  TREETOPCITY
# 10540  Assessment  TREETOPCITY
# 10542  Assessment  TREETOPCITY
#
#                                                     info  \
# 10535  The start game event is triggered at the very ...
# 10537  The start game event is triggered at the very ...
# 10538  The start game event is triggered at the very ...
# 10540  The start game event is triggered at the very ...
# 10542  The start game event is triggered at the very ...
#
#                                                     args    game_session_y  \
# 10535  [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 10537  [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
# 10538  [{"name":"game_time","type":"int","info":"mill...  9501794defd84e4d
# 10540  [{"name":"game_time","type":"int","info":"mill...  6bdf9623adc94d89
# 10542  [{"name":"game_time","type":"int","info":"mill...  901acc108f55a5a1
#
#                             title_y  num_correct  num_incorrect  accuracy  \
# 10535  Mushroom Sorter (Assessment)            1              0       1.0
# 10537  Mushroom Sorter (Assessment)            1              0       1.0
# 10538  Mushroom Sorter (Assessment)            1              1       0.5
# 10540  Mushroom Sorter (Assessment)            1              0       1.0
# 10542  Mushroom Sorter (Assessment)            1              0       1.0
#
#        accuracy_group
# 10535               3
# 10537               3
# 10538               2
# 10540               3
# 10542               3

# %%
ffd_df=final_filter_df[(final_filter_df['event_code']==4100)|(final_filter_df['event_code']==4110)]

# %%
ffd_df['title_x'].value_counts()
# Out:
# Bird Measurer (Assessment)      49556
# Cauldron Filler (Assessment)    41388
# Chest Sorter (Assessment)       32704
# Mushroom Sorter (Assessment)    31620
# Cart Balancer (Assessment)      24749
# Name: title_x, dtype: int64

# %%
f=ffd_df[ffd_df['title_x']=='Cart Balancer (Assessment)']
print(f['event_data'].value_counts())
# Out:
# {"correct":true,"left":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":34,"game_time":34508,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":24,"game_time":27757,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":27,"game_time":27108,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":38,"game_time":48493,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":33,"game_time":45672,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":25,"game_time":31864,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":23,"game_time":34378,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem06","weight":4},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":34,"game_time":50306,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":23,"game_time":26653,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":23,"game_time":25174,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":60,"game_time":81616,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":23,"game_time":27301,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":26,"game_time":25573,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":24,"game_time":25592,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":24,"game_time":27729,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":24,"game_time":26327,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":39,"game_time":50944,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":26,"game_time":34890,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":25,"game_time":40461,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem01","weight":1},{"id":"gem03","weight":3}],"right":[{"id":"gem02","weight":1},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem06","weight":4}],"event_count":33,"game_time":28059,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":25,"game_time":27773,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":37,"game_time":36370,"event_code":4100}      23
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem03","weight":3},{"id":"gem02","weight":1}],"event_count":28,"game_time":28745,"event_code":4100}      23
# {"correct":false,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3}],"event_count":30,"game_time":43335,"event_code":4100}                               23
# {"correct":false,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem05","weight":4}],"event_count":28,"game_time":19877,"event_code":4100}                                                                                                                                                                 20
# {"correct":false,"left":[],"right":[],"event_count":4,"game_time":5482,"event_code":4100}                                                                                                                                                                                                                     20
# {"correct":false,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem05","weight":4}],"event_count":31,"game_time":25096,"event_code":4100}                                                                                                                                                                 20
# {"correct":false,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem05","weight":4}],"event_count":9,"game_time":9595,"event_code":4100}                                                                                                                                                                   20
# {"correct":false,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem05","weight":4}],"event_count":13,"game_time":14290,"event_code":4100}                                                                                                                                                                 20
# {"correct":false,"left":[{"id":"gem07","weight":6},{"id":"gem01","weight":1},{"id":"gem02","weight":1}],"right":[{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem06","weight":4}],"event_count":38,"game_time":52283,"event_code":4100}     20
#                                                                                                                                                                                                                                                                                                               ..
# {"correct":true,"left":[{"id":"gem03","weight":3},{"id":"gem05","weight":4}],"right":[{"id":"gem04","weight":3},{"id":"gem06","weight":4}],"event_count":57,"game_time":65896,"event_code":4100}                                                                                                               1
# {"correct":true,"left":[{"id":"gem01","weight":1}],"right":[{"id":"gem02","weight":1}],"event_count":123,"game_time":109036,"event_code":4100}                                                                                                                                                                 1
# {"correct":true,"left":[{"id":"gem02","weight":1}],"right":[{"id":"gem01","weight":1}],"event_count":57,"game_time":81950,"event_code":4100}                                                                                                                                                                   1
# {"correct":true,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem08","weight":6}],"event_count":16,"game_time":13920,"event_code":4100}                                                                                                                                                                   1
# {"correct":true,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem08","weight":6}],"event_count":28,"game_time":22423,"event_code":4100}                                                                                                                                                                   1
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem01","weight":1},{"id":"gem03","weight":3}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem02","weight":1},{"id":"gem04","weight":3}],"event_count":65,"game_time":58951,"event_code":4100}       1
# {"correct":false,"left":[{"id":"gem05","weight":4},{"id":"gem07","weight":6}],"right":[{"id":"gem01","weight":1},{"id":"gem03","weight":3},{"id":"gem02","weight":1},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem06","weight":4}],"event_count":52,"game_time":96938,"event_code":4100}      1
# {"correct":false,"left":[{"id":"gem07","weight":6},{"id":"gem04","weight":3}],"right":[{"id":"gem05","weight":4},{"id":"gem01","weight":1},{"id":"gem03","weight":3},{"id":"gem06","weight":4},{"id":"gem02","weight":1},{"id":"gem08","weight":6}],"event_count":77,"game_time":73840,"event_code":4100}      1
# {"correct":true,"left":[{"id":"gem05","weight":4},{"id":"gem07","weight":6},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem06","weight":4},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":74,"game_time":79076,"event_code":4100}       1
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem04","weight":3},{"id":"gem05","weight":4},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem03","weight":3},{"id":"gem06","weight":4},{"id":"gem02","weight":1}],"event_count":25,"game_time":25344,"event_code":4100}       1
# {"correct":false,"left":[{"id":"gem07","weight":6},{"id":"gem02","weight":1},{"id":"gem05","weight":4},{"id":"gem01","weight":1},{"id":"gem08","weight":6}],"right":[{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem03","weight":3}],"event_count":43,"game_time":52616,"event_code":4100}      1
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem02","weight":1}],"event_count":23,"game_time":13709,"event_code":4100}       1
# {"correct":true,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem08","weight":6}],"event_count":10,"game_time":13477,"event_code":4100}                                                                                                                                                                   1
# {"correct":true,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem08","weight":6}],"event_count":8,"game_time":5390,"event_code":4100}                                                                                                                                                                     1
# {"correct":true,"left":[{"id":"gem03","weight":3},{"id":"gem07","weight":6},{"id":"gem02","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":17,"game_time":17616,"event_code":4100}                                                                                     1
# {"correct":false,"left":[{"id":"gem08","weight":6}],"right":[{"id":"gem06","weight":4},{"id":"gem04","weight":3}],"event_count":20,"game_time":19825,"event_code":4100}                                                                                                                                        1
# {"correct":true,"left":[{"id":"gem05","weight":4},{"id":"gem07","weight":6},{"id":"gem03","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem02","weight":1},{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem06","weight":4}],"event_count":26,"game_time":15681,"event_code":4100}       1
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem02","weight":1},{"id":"gem06","weight":4},{"id":"gem03","weight":3}],"right":[{"id":"gem08","weight":6},{"id":"gem04","weight":3},{"id":"gem01","weight":1},{"id":"gem05","weight":4}],"event_count":90,"game_time":87259,"event_code":4100}       1
# {"correct":true,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem08","weight":6}],"event_count":17,"game_time":16766,"event_code":4100}                                                                                                                                                                   1
# {"correct":true,"left":[{"id":"gem01","weight":1}],"right":[{"id":"gem02","weight":1}],"event_count":14,"game_time":12286,"event_code":4100}                                                                                                                                                                   1
# {"correct":false,"left":[],"right":[{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem03","weight":3},{"id":"gem01","weight":1},{"id":"gem05","weight":4},{"id":"gem02","weight":1},{"id":"gem08","weight":6},{"id":"gem07","weight":6}],"event_count":48,"game_time":30914,"event_code":4100}     1
# {"correct":true,"left":[{"id":"gem05","weight":4}],"right":[{"id":"gem06","weight":4}],"event_count":82,"game_time":93478,"event_code":4100}                                                                                                                                                                   1
# {"correct":false,"left":[{"id":"gem08","weight":6}],"right":[{"id":"gem07","weight":6},{"id":"gem06","weight":4},{"id":"gem04","weight":3},{"id":"gem03","weight":3},{"id":"gem05","weight":4},{"id":"gem01","weight":1},{"id":"gem02","weight":1}],"event_count":24,"game_time":31259,"event_code":4100}      1
# {"correct":false,"left":[],"right":[],"event_count":8,"game_time":19629,"event_code":4100}                                                                                                                                                                                                                     1
# {"correct":false,"left":[{"id":"gem03","weight":3},{"id":"gem05","weight":4},{"id":"gem07","weight":6},{"id":"gem01","weight":1},{"id":"gem02","weight":1}],"right":[{"id":"gem06","weight":4},{"id":"gem08","weight":6},{"id":"gem04","weight":3}],"event_count":29,"game_time":26913,"event_code":4100}      1
# {"correct":false,"left":[{"id":"gem08","weight":6}],"right":[{"id":"gem04","weight":3}],"event_count":11,"game_time":23774,"event_code":4100}                                                                                                                                                                  1
# {"correct":false,"left":[{"id":"gem06","weight":4},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6}],"event_count":11,"game_time":4879,"event_code":4100}                                                                                                                                         1
# {"correct":false,"left":[{"id":"gem07","weight":6}],"right":[{"id":"gem06","weight":4},{"id":"gem04","weight":3}],"event_count":13,"game_time":12523,"event_code":4100}                                                                                                                                        1
# {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4},{"id":"gem04","weight":3},{"id":"gem01","weight":1}],"right":[{"id":"gem08","weight":6},{"id":"gem03","weight":3},{"id":"gem06","weight":4},{"id":"gem02","weight":1}],"event_count":24,"game_time":19373,"event_code":4100}       1
# {"correct":false,"left":[{"id":"gem07","weight":6},{"id":"gem02","weight":1},{"id":"gem01","weight":1},{"id":"gem04","weight":3}],"right":[{"id":"gem08","weight":6},{"id":"gem05","weight":4},{"id":"gem03","weight":3}],"event_count":57,"game_time":89150,"event_code":4100}                                1
# Name: event_data, Length: 6687, dtype: int64

# %%
#Cart left right dictionaries
#Bird catterpillars list 3
#Cauldren  buckets 000 132, buckets_placed list 3
#Chest Sorter pillars list 3
#Mushroom stumps list 3

# %%
inst_ids=len(ffd_df['installation_id'].values)

# %%
col=['cart_left','cart_right','cat_p_l','cat_p_c',
     'cat_p_r','caul_l_b','caul_c_b','caul_r_b',
     'caul_l_a','caul_c_a','caul_r_a','mush_l',
     'mush_c','mush_r','chest_l', 'chest_c','chest_l']

# %%
import json
extracted_event_data = pd.io.json.json_normalize(ffd_df.event_data.apply(json.loads))

# %%
extracted_event_data.columns
# Out:
# Index(['buckets', 'buckets_placed', 'caterpillars', 'correct', 'duration',
#        'event_code', 'event_count', 'game_time', 'hats', 'left', 'pillars',
#        'right', 'stumps'],
#       dtype='object')

# %%
extracted_event_data.head()
# Out:
#   buckets buckets_placed caterpillars  correct  duration  event_code  \
# 0     NaN            NaN          NaN     True       NaN        4100
# 1     NaN            NaN          NaN     True       NaN        4100
# 2     NaN            NaN          NaN     True       NaN        4100
# 3     NaN            NaN          NaN     True       NaN        4100
# 4     NaN            NaN          NaN     True       NaN        4100
#
#    event_count  game_time hats left pillars right     stumps
# 0           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 1           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 2           44      31011  NaN  NaN     NaN   NaN  [1, 2, 4]
# 3           30      18026  NaN  NaN     NaN   NaN  [1, 2, 4]
# 4           30      18026  NaN  NaN     NaN   NaN  [1, 2, 4]

# %%
extracted_event_data['pillars'].value_counts()
# Out:
# []           8187
# [1, 2, 3]    4300
# [2, 1, 3]    2895
# [2, 3, 1]    2755
# [1, 3, 2]    2273
# [3, 2, 1]    2265
# [3, 1, 2]    2236
# [0]          1874
# [0, 0, 0]    1524
# [3]           563
# [1]           494
# [2]           432
# [0, 0]        416
# [0, 0, 3]     232
# [0, 0, 1]     208
# [2, 0, 0]     195
# [0, 3, 0]     176
# [1, 0, 0]     161
# [1, 0]        154
# [3, 0, 0]     148
# [0, 0, 2]     130
# [0, 1, 0]     124
# [0, 2, 0]     116
# [2, 3]         67
# [0, 3]         67
# [0, 2, 1]      58
# [2, 0]         55
# [1, 2]         54
# [0, 1]         54
# [0, 2]         49
# [1, 3]         47
# [0, 1, 3]      43
# [3, 0]         42
# [1, 3, 0]      39
# [3, 2, 0]      35
# [0, 2, 3]      28
# [1, 0, 3]      26
# [2, 1, 0]      25
# [3, 1]         19
# [3, 2]         18
# [1, 0, 2]      16
# [2, 0, 1]      15
# [1, 2, 0]      15
# [2, 1]         13
# [2, 3, 0]      13
# [0, 1, 2]      12
# [3, 1, 0]      11
# [2, 0, 3]       8
# [0, 3, 2]       6
# [0, 3, 1]       6
# [3, 0, 2]       4
# [3, 0, 1]       1
# Name: pillars, dtype: int64

# %%
#seperate based on type, this is how we will divide the attributes and receive the results
#To receive them each group will have to be analzed seperately 
#ignore specific attributes of the games and the overalapping attributes each can be generalized

# %%
filtered_df=full_tandt[(full_tandt['event_code']==4100) | (full_tandt['event_code']==4110)]

# %%
filtered_df.shape

# %%
filtered_df.head()

# %%
import json
extracted_event_data = pd.io.json.json_normalize(filtered_df.event_data.apply(json.loads))

# %%
extracted_event_data
